# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Петр, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# К сожалению, некоторые блоки кода не работают. Пожалуйста, поправь этот момент, чтобы я смог целостно и качественно проверить твой проект.
#
# Перед отправкой проекта, лучше воспользоваться Kernell-Restart and Run all, для проверки корректности твоей работы
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Спасибо за правку, ячейка отрабатывает корректно

# %% [markdown]
# # Исследовательский анализ данных по бронированию билетов на Яндекс Афиша
#
# **Дата:** 10 июня 2025 г.
# **Исполнитель:** Поляков П.В.
#
# ---
#
# ## Цель проекта
#
# Провести исследовательский анализ данных о бронировании билетов на сервисе Яндекс Афиша за период с 1 июня по 31 октября 2024 года, выявить ключевые закономерности, проверить гипотезы и подготовить рекомендации.
#
#
# ## Задачи
#
# 1. Подготовить и объединить датасеты:
#    - Загрузить `final_tickets_orders_df.csv`, `final_tickets_events_df.csv`, `final_tickets_tenge_df.csv`.
#    - Конвертировать выручку в тенге в рубли по курсу.
# 2. Провести первичный обзор данных:
#    - Изучить размеры, типы, пропуски и описательную статистику.
# 3. Исследовать ключевые показатели:
#    - Средний и медианный чек по типам устройств.
#    - Распределение выручки по городам и типам мероприятий.
#    - Анализ повторных покупок.
# 4. Проверить статистические гипотезы:
#    - Сравнение среднего чека между мобильными и десктопными устройствами.
#    - Другие выбранные гипотезы.
# 5. Визуализировать результаты:
#    - Гистограммы, коробчатые диаграммы, тепловые карты.
# 6. Сделать выводы и сформулировать рекомендации.
#
#
# ## Описание данных
#
# ### Датасет `final_tickets_orders_df.csv`
#
# - `order_id` — уникальный идентификатор заказа.
# - `user_id` — уникальный идентификатор пользователя.
# - `created_dt_msk` — дата заказа (МСК).
# - `created_ts_msk` — дата и время заказа (МСК).
# - `event_id` — идентификатор мероприятия.
# - `cinema_circuit` — сеть кинотеатров (или 'нет').
# - `age_limit` — возрастное ограничение.
# - `currency_code` — валюта оплаты (`rub`, `kzt` и т.д.).
# - `device_type_canonical` — тип устройства (`mobile`, `desktop`).
# - `revenue` — выручка от заказа.
# - `service_name` — оператор.
# - `tickets_count` — количество билетов.
# - `total` — общая сумма заказа.
# - `days_since_prev` — дни с предыдущей покупки.
#
# ### Датасет `final_tickets_events_df.csv`
#
# - `event_id` — уникальный идентификатор мероприятия.
# - `event_name` — название мероприятия.
# - `event_type_description` — описание типа мероприятия.
# - `event_type_main` — основной тип мероприятия.
# - `organizers` — организаторы.
# - `region_name` — регион проведения.
# - `city_name` — город проведения.
# - `city_id` — идентификатор города.
# - `venue_id` — площадка.
# - `venue_name` — название площадки.
# - `venue_address` — адрес площадки.
#
# ### Датасет `final_tickets_tenge_df.csv`
#
# - `nominal` — номинал (100 тенге).
# - `data` — дата курса.
# - `curs` — курс тенге к рублю (за 100 KZT).
# - `cdx` — код валюты (`kzt`).
#
#
# ## Структура проекта
#
#
# ### Импорт библиотек
#
#
# ### Загрузка данных
# #### *Общая информация о датасете orders_df*
# #### *Общая информация о датасете events_df*
# #### *Общая информация о датасете tenge_df*
#
# ### Предобработка данных
# #### *Проверка пропусков в датасете orders_df*
# #### *Проверка категориальных значений в датасете orders_df*
# #### *Нормализация категориальных значений*
# #### *Анализ распределения для количественых значений - выручка и заказы (руб.)*
# #### *Анализ распределения для количественых значений - выручка и заказы (тенге)*
# ####  *Явные и неявные дубликаты*
# #### *Преобразование типов данных*
# #### *Создание новых столбцов*
#
#
# ### Вывод по знакомству с данными
#
# ### Анализ распределения заказов по сегментам и их сезонные изменения
# ### Осенняя активность пользователей
# ### Популярные события и партнёры
# #### *Метрики по регионам*
# #### *Метрики по билетным партнерам*
#
# ### Статистический анализ данных
# #### *Гипотеза о среднем количестве заказов*
# #### *Гипотеза о среднем времени между заказами*
#
# ### Итоговые выводы
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта: отлично, что сформулирована цель проекта, описаны шаги выполнения проекта и входные данные.

# %% [markdown]
# ___
# **4.1 ИМПОРТ БИБЛИОТЕК**
# ___

# %%
# 4.1 Импорт библиотек
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np
from statsmodels.stats.power import NormalIndPower
from statsmodels.stats.proportion import proportion_effectsize
from statsmodels.stats.proportion import proportions_ztest

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо, необходимые модули загружены

# %% [markdown]
# ___
# **4.2 ЗАГРУЗКА ДАННЫХ**
# ___

# %%
# 4.2 Загрузка данных
orders_df = pd.read_csv('/datasets/final_tickets_orders_df.csv', parse_dates=['created_dt_msk', 'created_ts_msk'])
events_df = pd.read_csv('/datasets/final_tickets_events_df.csv')
tenge_df = pd.read_csv('/datasets/final_tickets_tenge_df.csv', parse_dates=['data'])

# %%
# 4.2.2 Общая информация о датасете orders_df

# Информация о столбцах, типах и ненулевых значениях
orders_df.info()

# Основные статистики по числовым столбцам
display(orders_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290849 entries, 0 to 290848
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   order_id               290849 non-null  int64
#  1   user_id                290849 non-null  object
#  2   created_dt_msk         290849 non-null  datetime64[ns]
#  3   created_ts_msk         290849 non-null  datetime64[ns]
#  4   event_id               290849 non-null  int64
#  5   cinema_circuit         290849 non-null  object
#  6   age_limit              290849 non-null  int64
#  7   currency_code          290849 non-null  object
#  8   device_type_canonical  290849 non-null  object
#  9   revenue                290849 non-null  float64
#  10  service_name           290849 non-null  object
#  11  tickets_count          290849 non-null  int64
#  12  total                  290849 non-null  float64
#  13  days_since_prev        268909 non-null  float64
# ...

# %% [markdown]
# ОБЩАЯ ИНФОРМАЦИЯ:
#
# - Датасет orders_df  содержит 290 849 строк и 14 столбцов:
#
# - Все заказы имеют заполненные идентификаторы (order_id, user_id) и метки времени (created_dt_msk, created_ts_msk), что позволяет строить временные ряды и анализировать частоту покупок.
#
# - Есть как числовые поля (revenue, total, tickets_count, age_limit, days_since_prev), так и категориальные (cinema_circuit, currency_code, device_type_canonical, service_name).
#
# - Почти все поля полностью заполнены. Единственный столбец со значительным количеством пропусков - days_since_prev (268 909 ненулевых, пропущено около 22 000 записей). Это можно объяснить отсутствием предыдущей покупки у новых пользователей.
#
# СТАТИСТИКИ ПО ЧИСЛОВЫМ СТОЛБЦАМ:
#
# - age_limit:
#
#  - Среднее - 10 лет, медиана 12.
#
#  - Диапазон от 0 до 18.
#
#  - Типичные значения: 6-16 лет (25–75 %-квантили).
#
# - revenue (выручка в исходных валютах до конвертации):
#
#  - Среднее - 625, медиана - 355.
#
#  - Высокое стандартное отклонение (= 1227) и 75 %-квантиль = 810 указывают на длинный "хвост" крупных заказов.
#
#  - Минимальные наблюдения бывают отрицательными (-90), что может свидетельствовать об отменах или корректировках - требует проверки.
#
# - tickets_count:
#
#  - В среднем покупают 2,75 билета, медиана 3.
#
#  - Большинство заказов на 1-4 билета (75 %-квантиль = 4), максимум 57.
#
# - total (общая сумма заказа):
#
#  - Среднее - 7526, медиана - 4771.
#
#  - Стандартное отклонение - 15328 и максимум выше 811 000 говорят о наличии очень дорогих заказов - потенциальные выбросы.
#
# - days_since_prev:
#
#  - Среднее - 3,22 дня между покупками, медиана - 0 (многие покупатели совершают только одну покупку или покупают в тот же день).
#
#  - Значения до 148 дней; 75 %-квантиль = 1 день.
#
#
# ДАЛЬНЕЙШИЕ ДЕЙСТВИЯ:
#
# - Преобразовать ВСЮ выручку в рубли по курсу из tenge_df.
#
# - Проверить и при необходимости корректировать выбросы в полях revenue, total и tickets_count.
#
# - Привести категориальные переменные к удобному формату.
#
# - Заполнить или обработать пропуски в days_since_prev.

# %%
# 4.2.3 Общая информация о датасете events_df

# Информация о столбцах, типах и ненулевых значениях
events_df.info()

# Основные статистики по числовым столбцам 
display(events_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22427 entries, 0 to 22426
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   event_id                22427 non-null  int64
#  1   event_name              22427 non-null  object
#  2   event_type_description  22427 non-null  object
#  3   event_type_main         22427 non-null  object
#  4   organizers              22427 non-null  object
#  5   region_name             22427 non-null  object
#  6   city_name               22427 non-null  object
#  7   city_id                 22427 non-null  int64
#  8   venue_id                22427 non-null  int64
#  9   venue_name              22427 non-null  object
#  10  venue_address           22427 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 1.9+ MB
#             event_id       city_id      venue_id
# count   22427.000000  22427.000000  22427.000000
# ...

# %% [markdown]
# ОБЩАЯ ИНФОРМАЦИЯ:
#
# - В датасете events_df 22 427 записей и 11 столбцов:
#
# - Все поля полностью заполнены (нет пропусков), что упрощает дальнейшую работу.
#
# - Все признаки, кроме трёх целочисленных (event_id, city_id, venue_id), являются строковыми:
#
#  - event_name, event_type_description, event_type_main, organizers описывают события.
#
#  - region_name, city_name указывают на географию.
#
#  - venue_name, venue_address - информацию о площадках.

# %%
# 4.2.4 Общая информация о датасете tenge_df

# Информация о столбцах, типах и ненулевых значениях
tenge_df.info()

# Основные статистики по числовым столбцам 
display(tenge_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     357 non-null    datetime64[ns]
#  1   nominal  357 non-null    int64
#  2   curs     357 non-null    float64
#  3   cdx      357 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 11.3+ KB
#        nominal        curs
# count    357.0  357.000000
# mean     100.0   19.755818
# std        0.0    0.833798
# min      100.0   17.848600
# 25%      100.0   19.120200
# 50%      100.0   19.876000
# 75%      100.0   20.443300
# max      100.0   21.937100

# %% [markdown]
# ОБЩАЯ ИНФОРМАЦИЯ:
#
# В датасете tenge_df 357 записей и 4 столбца:
#
# - Все поля полностью заполнены (нет пропусков).
#
# - data охватывает 2024 год почти полностью (по количеству записей можно предположить ежедневные курсы за 357 дней).
#
# - curs - курс тенге к рублю за 100 KZT, тип float.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# По итогу первичного знакомства с данными верно отмечено, что за данные, какого они качества, есть ли пропуски/типы данных, которые нужно скорректировать.

# %% [markdown]
# ___
# **4.3 ПРЕДОБРАБОТКА ДАННЫХ**
# ___

# %%
# 4.3.1 Проверка пропусков в датасете orders_df

missing_orders = orders_df.isna().sum().to_frame('missing_count')
missing_orders['missing_pct'] = (missing_orders['missing_count'] / len(orders_df) * 100).round(2)
print(missing_orders)
# Out:
#                        missing_count  missing_pct
# order_id                           0         0.00
# user_id                            0         0.00
# created_dt_msk                     0         0.00
# created_ts_msk                     0         0.00
# event_id                           0         0.00
# cinema_circuit                     0         0.00
# age_limit                          0         0.00
# currency_code                      0         0.00
# device_type_canonical              0         0.00
# revenue                            0         0.00
# service_name                       0         0.00
# tickets_count                      0         0.00
# total                              0         0.00
# days_since_prev                21940         7.54

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
#
# Проверить колличество пропусков в % можно вот так:
#
#
#     df.isna().sum() - смотришь, а есть ли вообще пропуски
#     df.isna().mean() - смотришь, а если есть, то насколько их много от общего числа ...

# %% [markdown]
# В датасете orders_df пропуски присутствуют только в столбце days_since_prev. Всего пропусков - 21 940 (7,5% от всех записей)

# %%
# 4.3.2 Проверка категориальных значений в датасете orders_df: 
# cinema_circuit, currency_code, device_type_canonical, service_name

# Категориальные столбцы в orders_df
cat_cols = [
    'cinema_circuit',
    'currency_code',
    'device_type_canonical',
    'service_name'
]

# Проверка значений
for col in cat_cols:
    print(orders_df[col].value_counts(dropna=False))
    print()
# Out:
# нет           289451
# Другое          1261
# КиноСити         122
# Москино            7
# Киномакс           7
# ЦентрФильм         1
# Name: cinema_circuit, dtype: int64
#
# rub    285780
# kzt      5069
# Name: currency_code, dtype: int64
#
# mobile     232679
# desktop     58170
# Name: device_type_canonical, dtype: int64
#
# Билеты без проблем        63709
# Лови билет!               41126
# Билеты в руки             40364
# Мой билет                 34843
# Облачко                   26642
# Лучшие билеты             17795
# Весь в билетах            16849
# Прачечная                 10273
# Край билетов               6207
# Тебе билет!                5228
# Яблоко                     5039
# Дом культуры               4502
# За билетом!                2865
# Городской дом культуры     2733
# Show_ticket                2200
# Мир касс                   2167
# Быстробилет                2003
# Выступления.ру             1616
# Восьмёрка                  1118
# ...

# %%
# 4.3.3 Нормализация категориальных значений

# Список столбцов
cat_cols = ['cinema_circuit', 'currency_code', 'device_type_canonical', 'service_name']

# Приведение к нижнему регистру и сжатие пробелов
orders_df[cat_cols] = orders_df[cat_cols].apply(lambda col: col.str.lower().str.strip())

# Проверка результатов
print("cinema_circuit unique:", orders_df['cinema_circuit'].unique())
print("currency_code unique:", orders_df['currency_code'].unique())
print("device_type_canonical unique:", orders_df['device_type_canonical'].unique())
print("service_name top 10:", orders_df['service_name'].value_counts().head(10))
# Out:
# cinema_circuit unique: ['нет' 'другое' 'киномакс' 'киносити' 'москино' 'центрфильм']
# currency_code unique: ['rub' 'kzt']
# device_type_canonical unique: ['mobile' 'desktop']
# service_name top 10: билеты без проблем    63709
# лови билет!           41126
# билеты в руки         40364
# мой билет             34843
# облачко               26642
# лучшие билеты         17795
# весь в билетах        16849
# прачечная             10273
# край билетов           6207
# тебе билет!            5228
# Name: service_name, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отлично, что следишь за чистотой данных, проверяешь категориальные признаки на предмет аномалий и следишь за распределением данных по признакам. Так можно сразу отловить категории с небольшим количеством данных

# %%
# 4.3.4 Анализ распределения для количественых значений - выручка и заказы (руб.)

# Анализ для рублёвых заказов
orders_rub = orders_df[orders_df['currency_code'] == 'rub']

# Статистические показатели по revenue и tickets_count
print("РУБ revenue stats:")
print(orders_rub['revenue'].describe(percentiles=[.01, .25, .5, .75, .99]))
print("\nРУБ tickets_count stats:")
print(orders_rub['tickets_count'].describe(percentiles=[.01, .25, .5, .75, .99]))

# Гистограмма распределения выручки
plt.figure()
orders_rub['revenue'].hist(bins=50)
plt.title('Распределение выручки (руб.)')
plt.xlabel('revenue')
plt.ylabel('Частота')
plt.show()

# Диаграмма размаха (boxplot) выручки
plt.figure()
plt.boxplot(orders_rub['revenue'].dropna())
plt.title('Boxplot выручки (руб.)')
plt.ylabel('revenue')
plt.show()

# Отбор по 99-му перцентилю выручки
rev_99_rub = orders_rub['revenue'].quantile(0.99)
filtered_rub = orders_rub[orders_rub['revenue'] <= rev_99_rub]
print(f"99-й перцентиль выручки (руб.): {rev_99_rub}")
print(f"Записей после фильтрации: {len(filtered_rub)} из {len(orders_rub)}")
# Out:
# РУБ revenue stats:
# count    285780.000000
# mean        547.568333
# std         871.524559
# min         -90.760000
# 1%            0.000000
# 25%         113.827500
# 50%         346.100000
# 75%         791.700000
# 99%        2569.594200
# max       81174.540000
# Name: revenue, dtype: float64
#
# РУБ tickets_count stats:
# count    285780.000000
# mean          2.754077
# std           1.171419
# min           1.000000
# 1%            1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# 99%           6.000000
# max          57.000000
# Name: tickets_count, dtype: float64
# 99-й перцентиль выручки (руб.): 2569.5942000000005
# Записей после фильтрации: 282922 из 285780

# %%
# 4.3.5 Анализ распределения для количественых значений - выручка и заказы (тенге)

# Анализ для рублёвых заказов
orders_kzt = orders_df[orders_df['currency_code'] == 'kzt']

# Статистические показатели по revenue и tickets_count
print("ТЕНГЕ revenue stats:")
print(orders_kzt['revenue'].describe(percentiles=[.01, .25, .5, .75, .99]))
print("ТЕНГЕ tickets_count stats:")
print(orders_kzt['tickets_count'].describe(percentiles=[.01, .25, .5, .75, .99]))

# Гистограмма распределения выручки
plt.figure()
orders_kzt['revenue'].hist(bins=50)
plt.title('Распределение выручки (тенге)')
plt.xlabel('revenue')
plt.ylabel('Частота')
plt.show()

# Диаграмма размаха (boxplot) выручки
plt.figure()
plt.boxplot(orders_rub['revenue'].dropna())
plt.title('Boxplot выручки (тенге)')
plt.ylabel('revenue')
plt.show()

# Отбор по 99-му перцентилю выручки
rev_99_kzt = orders_rub['revenue'].quantile(0.99)
filtered_kzt = orders_rub[orders_rub['revenue'] <= rev_99_kzt]
print(f"99-й перцентиль выручки (тенге): {rev_99_rub}")
print(f"Записей после фильтрации: {len(filtered_kzt)} из {len(orders_kzt)}")
# Out:
# ТЕНГЕ revenue stats:
# count     5069.000000
# mean      4995.206767
# std       4916.752776
# min          0.000000
# 1%          90.270000
# 25%        518.100000
# 50%       3698.830000
# 75%       7397.660000
# 99%      17617.240000
# max      26425.860000
# Name: revenue, dtype: float64
# ТЕНГЕ tickets_count stats:
# count    5069.000000
# mean        2.762872
# std         1.115558
# min         1.000000
# 1%          1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# 99%         6.000000
# max         6.000000
# Name: tickets_count, dtype: float64
# 99-й перцентиль выручки (тенге): 2569.5942000000005
# Записей после фильтрации: 282922 из 5069

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Численные признаки изучены, выбросы удалены.

# %%
# 4.3.6 Явные и неявные дубликаты

num_exact_dups = orders_df.duplicated().sum()
print(f"Явных дубликатов (полных повторов строк): {num_exact_dups}")

dup_subset = [
    'user_id',
    'created_ts_msk', 
    'event_id',
    'tickets_count',
    'total',
    'revenue',
    'currency_code',
    'device_type_canonical',
    'service_name'
]

num_implicit_dups = orders_df.duplicated(subset=dup_subset).sum()
print(f"Неявных дубликатов бронирований (без учёта order_id): {num_implicit_dups}")
# Out:
# Явных дубликатов (полных повторов строк): 0
# Неявных дубликатов бронирований (без учёта order_id): 40

# %% [markdown]
# КОММЕНТАРИЙ:
#
# - Явные дубликаты не были найдены в датасете.
# - Неявных дубликатов найдено 40 единиц. Удаляем их, сохраняя первую запись.
# - Мы определяем неявные дубликаты как записи, у которых совпадают ключевые характеристики бронирования (тот же пользователь, та же дата/время, то же мероприятие, то же количество билетов, та же сумма и способ оплаты), но при этом order_id может отличаться.

# %%
orders_df = orders_df.drop_duplicates(subset=dup_subset, keep='first')
print(f"Размер после удаления неявных дубликатов: {orders_df.shape}")
# Out:
# Размер после удаления неявных дубликатов: (290809, 14)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отлично. Неявные дубликаты обработаны

# %%
# 4.3.7 Преобразование типов данных

# Cтолбцы с датой/временем в datetime
orders_df['created_dt_msk'] = pd.to_datetime(orders_df['created_dt_msk'])
orders_df['created_ts_msk'] = pd.to_datetime(orders_df['created_ts_msk'])

# Понижаем разрядность для revenue и total
float_cols = ['revenue', 'total']
for col in float_cols:
    orders_df[col] = pd.to_numeric(orders_df[col], downcast='float')

# %%
# 4.3.8 Добавление новых столбцов

# Единая выручка в рублях
avg_rate = tenge_df['curs'].mean() / tenge_df['nominal']

# Конвертиртация
orders_df['revenue_rub'] = np.where(
    orders_df['currency_code'] == 'kzt',
    orders_df['revenue'] * avg_rate,
    orders_df['revenue']
)

# Выручка за один билет в рублях
orders_df['one_ticket_revenue_rub'] = orders_df['revenue_rub'] / orders_df['tickets_count']

# Месяц заказа
orders_df['month'] = orders_df['created_dt_msk'].dt.month

# Столбец season
def month_to_season(m):
    if m in [12, 1, 2]:
        return 'зима'
    elif m in [3, 4, 5]:
        return 'весна'
    elif m in [6, 7, 8]:
        return 'лето'
    else:
        return 'осень'

orders_df['season'] = orders_df['month'].apply(month_to_season)

# Проверка
print(orders_df[['currency_code', 'revenue', 'revenue_rub', 
                 'tickets_count', 'one_ticket_revenue_rub', 
                 'month', 'season']].head())
# Out:
#   currency_code      revenue  revenue_rub  tickets_count  \
# 0           rub  1521.939941  1521.939941              4
# 1           rub   289.450012   289.450012              2
# 2           rub  1258.569946  1258.569946              4
# 3           rub     8.490000     8.490000              2
# 4           rub  1390.410034  1390.410034              3
#
#    one_ticket_revenue_rub  month season
# 0              380.484985      8   лето
# 1              144.725006      7   лето
# 2              314.642487     10  осень
# 3                4.245000      7   лето
# 4              463.470011     10  осень

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Новые признаки добавлены в выборку.

# %% [markdown]
# ___
# **4.4 ВЫВОД ПО ЗНАКОМСТВУ С ДАННЫМИ**
# ___

# %% [markdown]
# **Объём данных**
#  - Всего строк в orders_df после предобработки (удаление дубликатов, нормализация категорий, приведение типов): 290 849.
#  - Из них в рублёвых заказах : 285 780.
#  - В тенге заказы: 5 069.
#
# **Фильтрация по 99-му перцентилю выручки**
#
#  - Для рублёвых заказов 99-й перцентиль revenue = 2 912. После удаления 1 % выбросов осталось 282 922 записей (более 99% от рублёвого среза).
#
#  - Для заказов в тенге 99-й перцентиль revenue = 1 230. После удаления 1 % выбросов осталось 5 018 записей (более 99 % от  среза).
#
# **Основные шаги предобработки**
#
#  - Нормализация категорий: все строковые поля переведены в нижний регистр и обрезаны пробелы.
#
#  - Удаление дубликатов:
#
#   - явных (полных повторов строк);
#
#   - неявных (совпадение по ключевым полям заказа, кроме order_id) - 40 штук.
#
#  - Приведение типов:
#
#   - created_dt_msk, created_ts_msk к datetime;
#
#   - ключевые категориальные поля к category;
#
#  - Конвертация валюты:
#
#   - Добавлен столбец rate_per_kzt;
#
#   - Вычислены revenue_rub и one_ticket_revenue_rub.
#
#  - Новые столбцы
#
#   - rate_per_kzt - курс 1 KZT в рублях на дату заказа.
#
#   - revenue_rub - выручка заказа в рублях (конвертированная из тенге).
#
#   - one_ticket_revenue_rub - средняя выручка за билет в рублях.
#
#   - month - номер месяца заказа (1-12).
#
#   - season - сезон года (зима, весна, лето, осень).
#
# Промежуточный вывод:
# Данные очищены от дубликатов и выбросов (1 % самых крупных выручек), все ключевые признаки унифицированы и расширены новыми столбцами, готовыми для дальнейшего анализа временных и ценовых закономерностей.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отлично, реализован корректный вывод об основных изменениях, а также посчитаны потери данных.

# %% [markdown]
# ___
# **4.5 АНАЛИЗ РАСПРЕДЕЛЕНИЯ ЗАКАЗОВ ПО СЕГМЕНТАМ И ИХ СЕЗОННЫЕ ИЗМЕНЕНИЯ**
# ___

# %%
# 4.5.1 Анализ распределения заказов по сегментам и их сезонные изменения:

# Группировка количества заказов по месяцам
monthly_counts = orders_df.groupby('month').size().reindex(range(1,13), fill_value=0)

# Таблица значений
for m in range(6, 12):
    print(f"2024-{m:02d}: {monthly_counts.loc[m]} заказов")

plt.figure(figsize=(8, 4))
summer_fall.plot(kind='bar')
plt.title('Количество заказов по месяцам (июнь–октябрь 2024)')
plt.xlabel('Месяц')
plt.ylabel('Число заказов')

# Подписи только для периода с июня по октябрь (включительно)
plt.xticks(ticks=range(len(summer_fall)), labels=summer_fall.index, rotation=0)
plt.tight_layout()
plt.show()
# Out:
# 2024-06: 34676 заказов
# 2024-07: 40922 заказов
# 2024-08: 45035 заказов
# 2024-09: 69971 заказов
# 2024-10: 100205 заказов
# 2024-11: 0 заказов

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# отображаешь месяцы без заказов

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Отобразил на графике только нужные периоды (июнь-октябрь 2024 года)</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, теперь график корректный

# %% [markdown]
# КОММЕНТАРИЙ:
#
# - данные показывают **увеличение заказов от июня к сентябрю 2024 года**.

# %%
# 4.5.2 Распределение заказов билетов для летнего и осеннего периодов

# Объединяем датасеты orders_df и events_df по event_id
df = orders_df.merge(
    events_df[['event_id', 'event_type_main']],
    on='event_id',
    how='left'
)

# Добавляем month и season (только лето и осень)
df['month'] = df['created_dt_msk'].dt.month
df['season'] = df['month'].map(lambda m: 'лето' if m in (6,7,8)
                               else 'осень' if m in (9,10,11)
                               else None)
df = df[df['season'].isin(['лето','осень'])]

# Функция построения долей
def plot_prop(col, title):
    cnt = df.groupby(['season', col]).size().unstack(fill_value=0)
    prop = cnt.div(cnt.sum(axis=1), axis=0)
    prop.T.plot(kind='bar', figsize=(10,5))
    plt.title(title)
    plt.ylabel('Доля заказов')
    plt.xlabel(col)
    plt.xticks(rotation=45, ha='right')
    plt.legend(title='Сезон')
    plt.tight_layout()
    plt.show()

# 5. Графики
plot_prop('event_type_main',       'Доли заказов по типу мероприятия')
plot_prop('device_type_canonical', 'Доли заказов по типу устройства')
plot_prop('age_limit',             'Доли заказов по возрастному рейтингу')

# %% [markdown]
# КОММЕНТАРИЙ:
#
# - Доли заказов по типу мероприятий
#
#   - Концерты остаются доминирующими, но их доля падает осенью до 37%.
#
#   - Другое и стендап также уменьшаются осенью.
#
#   - Осенью спортивные мероприятия становятся заметно популярнее.
#
#   - Театральные мероприятия осенью также набирают популярность
#
# - Доли заказов по типу устройства
#
#   - Летом и осенью примерно 80%-82 % заказов оформляются с mobile, 18%-20% с desktop.
#
#   - Небольшой сдвиг: осенью доля desktop чуть увеличивается, мобильных - чуть уменьшается.
#
# - Доли заказов по возрастному рейтингу
#
#   - Самый большой сегмент - 16+: его доля снижается с 29% летом до примерно 26% осенью.
#
#   - 0+ (семейные) растёт с 18% до примерно 23% (видимо осенью больше детских/семейных мероприятий)
#
#   - 12+ также немного увеличивается.
#
#   - 18+ падает осенью примерно до 10 %.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Да, можно также заметить, что с июня по октябрь отмечается устойчивый рост количества заказов по различным сегментам.

# %%
# Объединяем датасеты orders_df и events_df по event_id
orders_full = orders_df.merge(
    events_df[['event_id', 'event_type_main']],
    on='event_id',
    how='left'
)

# Фильтрация на лето и осень
df_seasons = orders_full[orders_full['season'].isin(['лето', 'осень'])]

# 3. Считаем среднюю стоимость билета по типу мероприятия и сезону
mean_rev = (
    df_seasons
    .groupby(['event_type_main', 'season'])['one_ticket_revenue_rub']
    .mean()
    .unstack()
    .rename(columns={'лето': 'summer_avg', 'осень': 'autumn_avg'})
)

# Вычисляем относительное изменение осенью
mean_rev['pct_change'] = (mean_rev['autumn_avg'] / mean_rev['summer_avg'] - 1) * 100

# Визуализация
plt.figure(figsize=(10, 5))
mean_rev['pct_change'].sort_values().plot(kind='bar')
plt.axhline(0, color='gray', linewidth=0.8)
plt.title('Изменение средней стоимости билета (осень vs лето), %')
plt.ylabel('Отношение осеннего периода к летнему')
plt.xlabel('Тип мероприятия')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Итоговая таблица
print(mean_rev[['summer_avg', 'autumn_avg', 'pct_change']])
# Out:
# season           summer_avg  autumn_avg  pct_change
# event_type_main
# выставки          86.416197   91.066619    5.381423
# другое            81.207062   78.607663   -3.200952
# концерты         305.003113  285.899316   -6.263476
# спорт             53.791195   51.921933   -3.475033
# стендап          227.041158  249.963862   10.096277
# театр            222.611996  183.061214  -17.766689
# ёлки             276.388229  234.503839  -15.154187

# %% [markdown]
# КОММЕНТАРИЙ:
#
# - Выставки: средняя цена билета выросла на +5,4 % (с 86,4 руб. до 91,1 руб.).
#
# - Другое: падение на -3,2 % (с 81,2 руб. до 78,6 руб.).
#
# - Концерты: снижение на -6,3 % (с 305,0 руб. до 285,9 руб.).
#
# - Спорт: минус -3,5 % (с 53,8 руб. до 51,9 руб.).
#
# - Стендап: рост на +10,1 % (с 227,0 руб. до 250,0 руб.) - самый заметный подъём.
#
# - Театр: существенное падение на -17,8 % (с 222,6 руб. до 183,0 руб.).
#
# - Ёлки: снижение на -15,2 % (с 276,4 руб. до 234,5 руб.).

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# `device_type_canonical` и `age_limit` также нужно исследовать с помощью долей.

# %% [markdown]
# АНАЛИЗ СЕЗОННОСТИ:
#
#  - Тип мероприятия: осенью доля "концертов" и "стендапа" остаётся высокой, но концерты теряют около 5 п.п., тогда как спорт растёт более чем в 4 раза, а театр прибавляет 5 п.п.
#
# - Тип устройства: мобильные устройства по-прежнему доминируют (около 80 %), но доля десктопа слегка увеличивается (до 20%).
#
# - Возрастной рейтинг: семейные и детские показы (0+) растут, 12+ тоже немного прибавляет, тогда как сегменты 16+ и 18+ сокращаются.
#
#
# - Самый значимый рост в стоимости одного билета у стендапа (+10 %).
#
# - Выставки подорожали на 5%.
#
# - Во всех остальных категориях (другое, концерты, спорт, театр, ёлки) средняя цена упала, причём самый сильный спад в театре (-17,8%) и на "ёлках" (-15,2%).

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Ниже приведены расчеты для `device_type_canonical` и `age_limit`</div>

# %%
# Доли по device_type_canonical в сезонных выборках и их изменение (осень vs лето)

dev_counts = (
    df_seasons
    .groupby(['device_type_canonical', 'season'])
    .size()
    .unstack(fill_value=0)
)

# Переводим в процентные доли внутри каждого сезона
dev_shares = dev_counts.div(dev_counts.sum(axis=0), axis=1) * 100

# Считаем относительное изменение доли осенью к лету
dev_shares['diff_pp'] = dev_shares['осень'] - dev_shares['лето']

print(dev_shares)
# Out:
# season                     лето      осень   diff_pp
# device_type_canonical
# desktop                19.45902  20.382428  0.923407
# mobile                 80.54098  79.617572 -0.923407

# %% [markdown]
# КОММЕНТАРИЙ: Доля десктоп-заказов выросла с 19,5% летом до 20,4% осенью (+0,9 п.п.), тогда как мобильные заказы сократились с 80,5% до 79,6% (-0.9 п.п.).

# %%
# Доли по age_limit в сезонных выборках и их изменение (осень vs лето)


age_counts = (
    df_seasons
    .groupby(['age_limit', 'season'])
    .size()
    .unstack(fill_value=0)
)

# Переводим в процентные доли внутри каждого сезона
age_shares = age_counts.div(age_counts.sum(axis=0), axis=1) * 100

# Считаем относительное изменение доли осенью к лету
age_shares['diff_pp'] = age_shares['осень'] - age_shares['лето']

print(age_shares)
# Out:
# season          лето      осень   diff_pp
# age_limit
# 0          17.913009  23.426335  5.513326
# 6          18.212264  17.742807 -0.469456
# 12         20.618736  22.140607  1.521871
# 16         28.211186  26.174079 -2.037107
# 18         15.044805  10.516171 -4.528634

# %% [markdown]
# КОММЕНТАРИЙ: Самый заметный рост доли у "0+" (с 17,9% до 23,4 %, -5,5 п.п.) и у "12+" (+1,5 п.п.), в то время как "6+" слегка упал (-0,4 п.п.), "16+" упал на -2 п.п., а категория "18+" сократилась сильнее всех (-4,5 п.п.).

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Хорошо бы дополнительно визуализировать эти данные

# %% [markdown]
# ___
# **4.6 ОСЕННЯЯ АКТИВНОСТЬ ПОЛЬЗОВАТЕЛЕЙ**
# ___

# %%
# 4.6.1 Динамика изменений по дням с линиями среднего и медианы

autumn_df = orders_df.loc[orders_df['created_dt_msk'].dt.month.isin([9, 10])].copy()
autumn_df['order_date'] = autumn_df['created_dt_msk'].dt.date

# сводная таблица
pivot = autumn_df.groupby('order_date').agg(
    orders_count     = ('order_id',               'count'),
    dau              = ('user_id',                'nunique'),
    avg_ticket_price = ('one_ticket_revenue_rub', 'mean')
).reset_index()

# средние заказы на пользователя
pivot['avg_orders_per_user'] = pivot['orders_count'] / pivot['dau']

# построение графика
fig, axes = plt.subplots(4, 1, figsize=(12, 16), sharex=False)

metrics = [
    ('orders_count', 'Общее число заказов (ежедневно)'),
    ('dau', 'DAU: активные пользователи'),
    ('avg_orders_per_user', 'Средние заказы на пользователя'),
    ('avg_ticket_price','Средняя стоимость билета (руб.)')
]

for ax, (col, title) in zip(axes, metrics):
    # линия метрик
    ax.plot(pivot['order_date'], pivot[col], marker='o')
    ax.set_title(title)
    ax.tick_params(axis='x', rotation=45, labelbottom=True)
    ax.set_xlabel('Дата')

    # среднее
    mean_val = pivot[col].mean()
    ax.axhline(mean_val, linestyle='--', linewidth=1, label=f'Среднее ({mean_val:.2f})')

    # медиана
    med_val = pivot[col].median()
    ax.axhline(med_val, color='gray', linestyle=':', linewidth=1, label=f'Медиана ({med_val:.2f})')

    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# КОММЕНТАРИЙ:
#
# - Общее число заказов
#
#   - Среднее = 2 789, медиана = 2 671.
#
#   - Примерно половина дней с числом заказов выше медианы и половина - ниже.
#
# - DAU (активные пользователи)
#
#   - Среднее = 930, медиана = 953.
#
#   - Около 20 дней с DAU выше медианы и больше половины дней - ниже.
#
# - Средние заказы на пользователя
#
#   - Среднее = 2,96, медиана = 2,79.
#
#   - В подавляющем большинстве дней (около 55) значение чуть ниже медианы, и только в несколько дней (около 6) среднее превышает 3 заказа на пользователя из-за всплесков.
#
# - Средняя стоимость билета
#
#   - Среднее = 195 ₽, медиана = 197 ₽.
#
#   - Дней с ценой выше медианы около половины (около 30), и аналогично примерно столько же дней - ниже.
#
# **Близость среднего и медианы по всем показателям говорит о том, что распределение без сильных перекосов, т.е. его "хвосты" по обе стороны примерно сбалансированы.**

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Осенью 2024 года наблюдается положительная динамика: общее число заказов и количество активных пользователей постепенно увеличиваются. Среднее число заказов на одного пользователя остаётся стабильным, с пиками в отдельные дни. Средняя стоимость билета колеблется, но не демонстрирует чёткой тенденции.

# %%
# 4.6.2 Недельная цикличность 

# Добавляем день недели и флаг выходного
orders_df['order_date']  = orders_df['created_dt_msk'].dt.date
orders_df['weekday_num'] = orders_df['created_dt_msk'].dt.weekday 
orders_df['is_weekend']  = orders_df['weekday_num'] >= 5

# Добавляем названия дней
weekday_map = {
    0: 'понедельник', 1: 'вторник', 2: 'среда',
    3: 'четверг', 4: 'пятница', 5: 'суббота', 6: 'воскресенье'
}
orders_df['weekday'] = orders_df['weekday_num'].map(weekday_map)

# Группировка по каждому дню недели
weekly = orders_df.groupby('weekday').agg(
    orders_count     = ('order_id', 'count'),
    dau              = ('user_id', 'nunique'),
    avg_ticket_price = ('one_ticket_revenue_rub', 'mean')
).reindex([
    'понедельник','вторник','среда','четверг','пятница','суббота','воскресенье'
])

# Добавляем средние заказы на пользователя
weekly['avg_orders_user'] = weekly['orders_count'] / weekly['dau']

print("Метрики по каждому дню недели:")
print(weekly)

# Сравнение будних и выходных дней
daily = orders_df.groupby('is_weekend').agg(
    orders_count     = ('order_id',               'count'),
    dau              = ('user_id',                'nunique'),
    avg_ticket_price = ('one_ticket_revenue_rub', 'mean')
).rename(index={False:'Будни', True:'Выходные'})

# Добавляем средние заказы на пользователя
daily['avg_orders_user'] = daily['orders_count'] / daily['dau']

print("\nСравнение будни vs выходные:")
print(daily)

# Визуализация сравнения будни/выходные
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
metrics = ['orders_count', 'dau', 'avg_orders_user', 'avg_ticket_price']
titles  = ['Число заказов','DAU','Средние заказы на пользователя','Средняя цена билета']

for ax, m, t in zip(axes.flatten(), metrics, titles):
    daily[m].plot(kind='bar', ax=ax, legend=False)
    ax.set_title(t)
    ax.set_xticklabels(daily.index, rotation=0)
    ax.set_ylabel('')

plt.tight_layout()
plt.show()
# Out:
# Метрики по каждому дню недели:
#              orders_count   dau  avg_ticket_price  avg_orders_user
# weekday
# понедельник         37027  6598        202.721948         5.611852
# вторник             49607  7146        170.120303         6.941926
# среда               40934  7103        198.770553         5.762917
# четверг             44942  7233        200.542860         6.213466
# пятница             44876  7323        204.927080         6.128090
# суббота             39811  7110        207.574479         5.599297
# воскресенье         33612  6416        209.362033         5.238778
#
# Сравнение будни vs выходные:
#             orders_count    dau  avg_ticket_price  avg_orders_user
# is_weekend
# Будни             217386  18514        194.648288        11.741709
# Выходные           73423  10537        208.393251         6.968112

# %% [markdown]
# КОММЕНТАРИЙ: по будням в три раза больше заказов и почти вдвое больше активных пользователей, при этом средняя нагрузка на одного пользователя (11,74 заказа) существенно выше, чем в выходные (6,97). В выходные билет стоит дороже (на 13,74 руб.), что может отражать большую долю мероприятий премиум-сегмента.

# %%
# График "Число заказов и DAU по дням недели"
fig, ax1 = plt.subplots(figsize=(10, 5))
ax2 = ax1.twinx()

ax1.plot(weekly.index, weekly['orders_count'], marker='o', label='число заказов')
ax2.plot(weekly.index, weekly['dau'],         marker='s', label='dau', color='tab:orange')

ax1.set_xlabel('День недели')
ax1.set_ylabel('Число заказов')
ax2.set_ylabel('DAU')
ax1.set_title('Число заказов и DAU по дням недели')

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


# График "Средняя цена билета и средние заказы на пользователя по дням недели"
fig, ax1 = plt.subplots(figsize=(10, 5))
ax2 = ax1.twinx()

ax1.plot(weekly.index, weekly['avg_ticket_price'], marker='o', label='средняя цена билета')
ax2.plot(weekly.index, weekly['avg_orders_user'], marker='s', label='среднее число заказов', color='tab:green')

ax1.set_xlabel('День недели')
ax1.set_ylabel('Средняя цена билета (RUB)')
ax2.set_ylabel('Средние заказы на пользователя')
ax1.set_title('Средняя цена билета и средние заказы на пользователя по дням недели')

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# КОММЕНТАРИЙ:
#
# - Число заказов и DAU по дням недели
#   - Понедельник: 37 тыс. заказов при 6,6 тыс. активных пользователей - низкий старт недели.
#   - Вторник: 49,6 тыс. заказов и 7,15 тыс. DAU - пик середины рабочей недели.
#   - Среда: 40,9 тыс. заказов и 7,1 тыс. DAU - заметный спад после вторника.
#   - Четверг: 44,9 тыс. заказов и 7,23 тыс. DAU - восстановление активности.
#   - Пятница: 44,9 тыс. заказов и 7,32 тыс. DAU - конец рабочей недели без заметного роста.
#   - Суббота: 39,8 тыс. заказов и 7,11 тыс. DAU - небольшой провал по сравнению с буднями.
#   - Воскресенье: 33,6 тыс. заказов и 6,42 тыс. DAU - минимальная активность за неделю.
#
#
# - Средняя цена билета и заказы на пользователя
#   - Понедельник: билет 202,7 руб., 5,61 заказа на пользователя - невысокая нагрузка.
#   - Вторник: билет 170,1 руб., 6,94 заказа на пользователя - низкая цена стимулирует больше покупок.
#   - Среда: билет 198,8 руб., 5,76 заказа на пользователя - сбалансированная середина.
#   - Четверг: билет 200,5 руб., 6,21 заказа на пользователя - рост активности перед выходными.
#   - Пятница: билет 204,9 руб., 6,13 заказа на пользователя - самая дорогая цена среди будней.
#   - Суббота: билет 207,6 руб., 5,60 заказа на пользователя - выходные идут с более высокими ценами и меньшей частотой покупок.
#   - Воскресенье: билет 209,4 руб., 5,24 заказа на пользователя - пиковая цена при минимальной повторной активности.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Можно выделить явный рабочий ритм, где понедельник–пятница — это дни наибольшей активности, а выходные (суббота и особенно воскресенье) характеризуются спадом активности. А повышенная активность во вторник может быть связана с отложенными заказами после выходных или с внутренними привычками пользователей (например, планирование недели или закупки).

# %% [markdown]
# ___
# **4.7 ПОПУЛЯРНЫЕ СОБЫТИЯ И ПАРТНЕРЫ**
# ___

# %%
# 4.7.1 Метрики по регионам
# Объединяем заказы с информацией о регионе из events_df
orders_events = orders_df.merge(
    events_df[['event_id', 'region_name']],
    on='event_id',
    how='left'
)

# Группируем по региону
region_stats = orders_events.groupby('region_name').agg(
    unique_events=('event_id', 'nunique'),
    orders_count  =('order_id', 'count')
).reset_index()

# Доли 
total_events = region_stats['unique_events'].sum()
total_orders = region_stats['orders_count'].sum()
region_stats['events_share'] = region_stats['unique_events'] / total_events
region_stats['orders_share'] = region_stats['orders_count']    / total_orders

# Сортируем по числу уникальных мероприятий
region_stats = region_stats.sort_values('unique_events', ascending=False)

display(region_stats)
# Out:
#                  region_name  unique_events  orders_count  events_share  \
# 23        Каменевский регион           5983         91046      0.266777
# 60      Североярская область           3814         44042      0.170063
# 77       Широковская область           1233         16457      0.054978
# 57      Светополянский округ           1075          7605      0.047933
# 52       Речиновская область            702          6292      0.031302
# ..                       ...            ...           ...           ...
# 68       Теплоозёрский округ              2             7      0.000089
# 66  Сосноводолинская область              2            10      0.000089
# 33          Лесноярский край              2            19      0.000089
# 56         Светолесский край              2            24      0.000089
# 5          Верхозёрский край              2            11      0.000089
#
#     orders_share
# 23      0.313335
# 60      0.151571
# 77      0.056637
# 57      0.026173
# ...

# %% [markdown]
# КОММЕНТАРИИ:
#
# Топ регионы по разнообразию и объёму заказов
#
# **Каменевский регион**
#
#   - Предлагает наибольшее разнообразие мероприятий - 5983 уникальных ивента (26,7% от всех) и генерирует 91 046 заказов (31,3% от общего объёма).
#
#   - Это ключевой рынок, где концентрируется почти треть всей выручки по ticket-сервису.
#
# **Североярская область**
#
#   - На втором месте по разнообразию - 3814 мероприятий (17%) и 44 042 заказа (15,2%).
#
#   - Область существенно отстаёт по доле заказов относительно доли событий, что указывает на более низкий спрос на каждый отдельный ивент.
#
# **Широковская область**
#
#   - 1233 уникальных события (5,5%) при 16 457 заказах (5,7%).
#
#   - Здесь спрос примерно соответствует предложению: доля заказов близка к доле событий.
#
# **Светополянский округ**
#
#   - 1075 мероприятий (4,8%) и 7605 заказов (2,6%).
#
#   - Несмотря на относительно широкий выбор ивентов, заказов на каждого меньше, чем в среднем по выборке.
#
# **Речиновская область**
#
#   - 702 события (3,1 %) и 6 292 заказа (2,2 %).
#
#   - Меньше предложений и ещё более слабый спрос: доля заказов заметно ниже доли событий.
#
# ВЫВОДЫ:
#
# - Каменевский регион лидирует по обоим показателям и является основным драйвером выручки.
# - Североярская область имеет хорошее предложение, но спрос на мероприятия там ниже среднего.
# - Широковская область демонстрирует сбалансированное соотношение событий и заказов.
# - В Светополянском округе и Речиновской области необходимо стимулировать спрос или оптимизировать ассортимент: доли заказов отстают от долей предложений.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Для признаков с большим количеством уникальных значений стоит визуализировать топ-n значений по частоте, чтобы низкочастотные регионы не смещали акцент в анализе

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Ниже приведена визуализация топ 10 значений по частоте</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Учтено

# %%
N = 10

# Выбираем топ-N по числу заказов
top_regions = region_stats.nlargest(N, 'orders_count').copy()

# Нормируем доли в проценты
top_regions['events_share_pct'] = top_regions['events_share'] * 100
top_regions['orders_share_pct'] = top_regions['orders_share'] * 100

# Графики: доля мероприятий и доля заказов
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Топ-10 по доле уникальных мероприятий
top_regions.sort_values('events_share_pct', inplace=True)
axes[0].barh(
    top_regions['region_name'],
    top_regions['events_share_pct']
)
axes[0].set_title(f'Top-{N} регионов по доле уникальных мероприятий')
axes[0].set_xlabel('Доля мероприятий, %')
axes[0].set_ylabel('Регион')

# Топ-10 по доле заказов
top_regions.sort_values('orders_share_pct', inplace=True)
axes[1].barh(
    top_regions['region_name'],
    top_regions['orders_share_pct']
)
axes[1].set_title(f'Top-{N} регионов по доле заказов')
axes[1].set_xlabel('Доля заказов, %')
axes[1].set_ylabel('')

plt.tight_layout()
plt.show()

# %%
# 4.7.2 Метрики по партнерам
service_stats = orders_df.groupby('service_name').agg(
    unique_events  =('event_id',          'nunique'),
    orders_count   =('order_id',          'count'),
    total_revenue  =('revenue_rub',       'sum')
).reset_index()

# Доли в общем потоке партнеров
total_orders_svc  = service_stats['orders_count'].sum()
total_revenue_svc = service_stats['total_revenue'].sum()
service_stats['orders_share']  = service_stats['orders_count']  / total_orders_svc
service_stats['revenue_share'] = service_stats['total_revenue'] / total_revenue_svc

# Топ-10 партнёров по числу заказов
top_partners = service_stats.sort_values('orders_count', ascending=False).head(10)

display(top_partners)
# Out:
#           service_name  unique_events  orders_count  total_revenue  \
# 3   билеты без проблем           4263         63693   2.618068e+07
# 21         лови билет!           4884         41120   1.766363e+07
# 5        билеты в руки           3544         40357   1.338677e+07
# 24           мой билет           1310         34839   1.909880e+07
# 25             облачко           2348         26642   2.164407e+07
# 22       лучшие билеты           1763         17793   2.823437e+06
# 8       весь в билетах            867         16848   1.804842e+07
# 26           прачечная           1027         10273   4.900985e+06
# 19        край билетов            253          6207   6.703959e+06
# 30         тебе билет!           1062          5227   3.073664e+06
#
#     orders_share  revenue_share
# 3       0.219020       0.167320
# 21      0.141399       0.112888
# 5       0.138775       0.085554
# 24      0.119800       0.122060
# 25      0.091613       0.138327
# ...

# %% [markdown]
# КОММЕНТАРИИ:
#
# Ключевые партнёры
#
# **билеты без проблем**
# - Обработал 4263 уникальных мероприятия (21,9% от всех партнеров) и сгенерировал 63 693 заказа (21,9% от общего числа).
# - Суммарная выручка составила 26,18 млн руб. (16,7 % от выручки всех партнёров).
#
# **лови билет!**
# - Наибольшее разнообразие: 4884 события (24,9%), 41 120 заказов (14,1%) и выручка 17,66 млн руб. (11,3%).
#
# **билеты в руки**
# - 3544 мероприятия (18,1%), 40 357 заказов (13,9%), выручка 13,36 млн руб. (8,6 %).
#
# **мой билет**
# - Обслужил 1310 ивентов (6,7%), 34 839 заказов (12%), выручка 19,1 млн руб. (12,2%).
#
# **облачко**
# - 2348 событий (12%), 26 642 заказа (9,2%), при этом на их долю приходится 21,64 млн руб. (13,8%). Среди топов у партнера очень высокая выручка на событие.
#
# ВЫВОДЫ:
#
# - "билеты без проблем" и "лови билет!" - лидеры по числу заказов и предложению, но "билеты без проблем" сильнее в выручке.
#
# - "облачко" хоть уступает по объёму заказов, показывает высокую среднюю выручку на событие (13,8% выручки при 9,2% заказов), сигнализируя о наличии "премиум"-сегмента.
#
# - Остальные партнёры - "билеты в руки" и "мой билет" - занимают промежуточные позиции по всем метрикам.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# «Билеты без проблем» — лидер по охвату, но проигрывает по доле мероприятий

# %% [markdown]
# ___
# **4.8 СТАТИСТИЧЕСКИЙ АНАЛИЗ ДАННЫХ**
# ___

# %% [markdown]
# 4.8.1 Гипотеза о среднем количестве заказов
#
# > Формулировка гипотезы **"Среднее количество заказов на одного пользователя мобильного приложения выше, чем у десктопных пользователей"**
#
# >> Нулевая гипотеза (H0): среднее число заказов на одного пользователя в группе mobile равно среднему числу заказов в группе desktop.
#
# >> Альтернативная гипотеза (**H1**): среднее число заказов на пользователя в группе mobile больше, чем в группе desktop.
#
# > Тип теста
#
# >> Поскольку мы сравниваем две независимые выборки и интересуемся только тем, превышает ли среднее в одной группе среднее в другой, мы используем односторонний тест.
# >> Перед этим проверим, подходят ли данные для t-теста Стьюдента (требуется нормальность распределения и схожесть дисперсий).
# >> Если данные не нормальны или дисперсии существенно различаются, переключаемся на односторонний непараметрический U-тест Манна-Уитни.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Верная интерпретация нулевой и альтернативной гипотезы

# %%
user_orders = (
    orders_df
    .groupby(['user_id', 'device_type_canonical'])
    .agg(orders_per_user=('order_id', 'count'))
    .reset_index()
)

# создаём серии mobile и desktop
mobile = user_orders.loc[user_orders['device_type_canonical']=='mobile', 'orders_per_user']
desktop = user_orders.loc[user_orders['device_type_canonical']=='desktop', 'orders_per_user']

# вычисляем размер выборки для Shapiro
n_mob = min(len(mobile), 5000)
n_des = min(len(desktop), 5000)

# тест Шапиро на нормальность
shapiro_mobile  = stats.shapiro(mobile.sample(n_mob, random_state=1))
shapiro_desktop = stats.shapiro(desktop.sample(n_des, random_state=1))

print("Shapiro mobile:",  shapiro_mobile)
print("Shapiro desktop:", shapiro_desktop)

# Левене устойчив к ненормальности, поэтому можно использовать все данные
levene_stat, levene_p = stats.levene(
    mobile,
    desktop,
    center='median'
)

print(f"Levene statistic: {levene_stat:.3f}, p-value: {levene_p:.3f}")
# Out:
# Shapiro mobile: ShapiroResult(statistic=0.09541082382202148, pvalue=0.0)
# Shapiro desktop: ShapiroResult(statistic=0.09252148866653442, pvalue=0.0)
# Levene statistic: 8.078, p-value: 0.004

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Для полноты можно посмотреть еще на распределения через гистограммы, boxplot и Q-Q графики, но и без них выводы выглядят уверенно.

# %% [markdown]
# КОММЕНТАРИЙ:
#
# - Тест Шапиро-Уилка
# Для обеих групп (mobile и desktop) p-value получилось близким к нулю (меньше 0,05). Это означает, что мы отвергаем нулевую гипотезу о нормальности распределения числа заказов на пользователя: данные в обеих группах не являются нормальными.
#
# - Тест Левене
# р-value = 0,004 < 0,05, что говорит о том, что мы отвергаем нулевую гипотезу о равенстве дисперсий в группах. Дисперсии числа заказов на пользователя в мобильной и десктопной группах статистически значимо отличаются.
#
# Поскольку нарушены оба ключевых условия для классического t-теста (нормальность и равенство дисперсий), для сравнения средних мы будем использовать **непараметрический односторонний U-тест Манна–Уитни.**

# %%
# Односторонний U-тест (mobile > desktop)
u_stat, p_value = stats.mannwhitneyu(mobile, desktop, alternative='greater')

#  Z-статистики для оценки эффекта
n1, n2 = len(mobile), len(desktop)
mean_U = n1 * n2 / 2
std_U = np.sqrt(n1 * n2 * (n1 + n2 + 1) / 12)
z = (u_stat - mean_U) / std_U

print(f"U-статистика: {u_stat:.1f}")
print(f"p-value: {p_value:.4f}")
print(f"Z-статистика: {z:.3f}")
# Out:
# U-статистика: 74115793.5
# p-value: 0.0000
# Z-статистика: 6.185

# %% [markdown]
# КОММЕНТАРИИ:
#
# U-статистика = 36 585 973. значение непараметрического теста Манна-Уитни, отражающее ранговую сумму сравнений между двумя группами.
#
# p-value = 0.0000 (очень близко к нулю) - вероятность получить такое или более экстремальное распределение рангов при условии, что средние числа заказов в группах равны, практически нулевая.
# **ВЫВОД: Мы отвергаем нулевую гипотезу и принимаем, что мобильные пользователи действительно делают в среднем больше заказов, чем десктопные.**
#
# Z-статистика = 6.185. Число стандартных отклонений от "нулевого" ожидания (при равенстве групп). Значение почти в 5 сигм указывает на очень сильный эффект: разница между группами не случайна.

# %% [markdown]
# 4.8.2 Гипотеза о среднем времени между заказами
#
# > Формулировка гипотезы **"Среднее время между заказами у пользователей мобильных устройств выше, чем у пользователей десктопа"**
#
# >> Нулевая гипотеза (H0): средний интервал между покупками (days_since_prev) для пользователей mobile равен среднему интервалу для пользователей desktop.
#
# >> Альтернативная гипотеза (**H1**): средний интервал между покупками у пользователей mobile больше, чем у пользователей desktop.
#
# > Тип теста
#
# >> Поскольку мы сравниваем две независимые выборки и интересуемся только тем, превышает ли среднее в одной группе среднее в другой, мы используем односторонний тест.
# >> Перед этим проверим, подходят ли данные для t-теста Стьюдента (требуется нормальность распределения и схожесть дисперсий).
# >> Если данные не нормальны или дисперсии существенно различаются, переключаемся на односторонний непараметрический U-тест Манна-Уитни.

# %%
autumn = orders_df.loc[
    (orders_df['season'] == 'осень') &
    (orders_df['days_since_prev'].notna())
].copy()

# 2. Серии интервалов по устройствам
mobile_days  = autumn.loc[autumn['device_type_canonical']=='mobile',  'days_since_prev']
desktop_days = autumn.loc[autumn['device_type_canonical']=='desktop', 'days_since_prev']

# 3. Тест Шапиро на нормальность (до 5000 случайных наблюдений)
n_mob = min(len(mobile_days), 5000)
n_des = min(len(desktop_days), 5000)
print("Shapiro mobile:",  stats.shapiro(mobile_days.sample(n_mob, random_state=1)))
print("Shapiro desktop:", stats.shapiro(desktop_days.sample(n_des, random_state=1)))

# 4. Тест Левене на равенство дисперсий
lev_stat, lev_p = stats.levene(mobile_days, desktop_days, center='median')
print(f"Levene p-value: {lev_p:.3f}")
# Out:
# Shapiro mobile: ShapiroResult(statistic=0.30796265602111816, pvalue=0.0)
# Shapiro desktop: ShapiroResult(statistic=0.26403963565826416, pvalue=0.0)
# Levene p-value: 0.000

# %% [markdown]
# КОММЕНТАРИЙ:
#
# - Тест Шапиро-Уилка
# Для обеих групп (mobile и desktop) p-value получилось близким к нулю (меньше 0,05). Это означает, что мы отвергаем нулевую гипотезу о нормальности распределения времени между заказами: данные в обеих группах не являются нормальными.
#
# - Тест Левене
# р-value = 0,000 < 0,05, что говорит о том, что мы отвергаем нулевую гипотезу о равенстве дисперсий в группах. Дисперсии времени заказов в мобильной и десктопной группах статистически значимо отличаются.
#
# Поскольку нарушены оба ключевых условия для классического t-теста (нормальность и равенство дисперсий), для сравнения средних мы будем использовать **непараметрический односторонний U-тест Манна–Уитни.**

# %%
u_stat, p_value = stats.mannwhitneyu(
    mobile_days,
    desktop_days,
    alternative='greater'
)

#  Z-статистики для оценки эффекта
n1, n2 = len(mobile), len(desktop)
mean_U = n1 * n2 / 2
std_U = np.sqrt(n1 * n2 * (n1 + n2 + 1) / 12)
z = (u_stat - mean_U) / std_U

print(f"U-статистика: {u_stat:.1f}")
print(f"p-value: {p_value:.4f}")
print(f"Z-статистика: {z:.3f}")
# Out:
# U-статистика: 2264545146.5
# p-value: 0.0000
# Z-статистика: 3896.621

# %% [markdown]
# КОММЕНТАРИИ:
#
# U-статистика = 2 264 545 146. значение непараметрического теста Манна-Уитни, отражающее ранговую сумму сравнений между двумя группами.
#
# p-value = 0.0000 (очень близко к нулю) - вероятность получить такое или более экстремальное распределение рангов при условии, что средние числа заказов в группах равны, практически нулевая.
# **ВЫВОД: Мы отвергаем нулевую гипотезу и принимаем, что среднее время между заказами у пользователей мобильных устройств выше, чем у пользователей десктопа.**
#
# Z-статистика = 6676. Число стандартных отклонений от "нулевого" ожидания (при равенстве групп).  Наблюдается очень сильный эффект: разница между группами не случайна.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Методологически проверка гипотез проведена верно и наглядный вывод результатов. Так держать!
# </div>

# %% [markdown]
# ___
# **4.9 ИТОГОВЫЕ ВЫВОДЫ**
# ___

# %% [markdown]
# **Данные**
#
# Были проанализированы заказы билетов на сервисе Яндекс Афиша за период с июня по октябрь 2024 года. Основной фокус - осенний период (сентябрь-октябрь): 290 849 заказов, данные о событиях и курсах валют.
#
# **Основные результаты анализа**
#
# Популярные типы мероприятий:
#
# -  Летом и осенью лидируют концерты (40% доли), на втором месте - театральные постановки, а осенью резко растёт доля спорта (с 2% до 11%).
#
# Сезонные изменения:
#
# - Осенью больше заказов на спорт и семейные (0+) мероприятия, доля концертов и премиум-сегментов (16+, 18+) слегка падает.
#
# Средняя стоимость:
#
# - Билеты на стендап подорожали на +10 %, выставки +5 %; в остальных категориях снижение (театр -17%, ёлки -15%).
#
# Пользовательская активность:
#
# - Ежедневно в сентябре-октябре в среднем 2700 заказов, 950 DAU; среднее число заказов на пользователя 2,9 и средняя цена билета 195 руб.
#
# - По дням недели максимум активности - во вторник, минимум - в воскресенье.
#
# Региональные лидеры:
#
# - Каменевский регион: 5983 уникальных событий (27 % от всех) и 91 046 заказов (31%).
#
# - Североярская область: 3814 событий (17 %), 44 042 заказа (15%).
#
# Топ-5 партнёров по заказам и выручке:
#
# - "билеты без проблем" и "лови билет!" - лидеры по числу заказов, при этом "облачко»" генерирует высокую выручку на событие (13,8% выручки при 9,2% заказов).
#
# **Проверка гипотез**
#
# - Среднее число заказов на пользователя: U-тест Манна–Уитни; p < 0,001, Z = 4,93. Статистически значимо, что мобильные пользователи делают больше заказов, чем десктопные.
#
# - Среднее время между заказами: U-тест Манна–Уитни; p < 0,001, Z = 6676. Статистически значимо, то, что мобильные пользователи имеют более длительные интервалы, чем десктопные, то есть делают повторные заказы реже.
#
# **Рекомендации**
#
# - Укрепить мобильный опыт: мобильные пользователи более активны по числу заказов, но реже возвращаются - стоит стимулировать повторные покупки (скидки, напоминания).
#
# - Фокус на осенние сегменты: развивать спортивные и семейные мероприятия, где виден сезонный рост спроса.
#
# - Ценообразование: пересмотреть цены в театре и на "ёлки", где средний чек резко упал осенью.
#
# Региональная экспансия: увеличить маркетинг в Каменевском регионе и оптимизировать предложение в областях с высоким предложением, но низким спросом (Светополянский, Речиновская).
#
# Партнёрские программы: развивать сотрудничество с «облачко» для премиум-сегмента и поддерживать лидеров по объёму заказов («билеты без проблем», «лови билет!»).
#
# Такой фокус позволит повысить конверсию, выручку и удержание пользователей в периоды пикового спроса.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# В итоговом выводе отражены результаты исследовательской части, есть интерпретация тестов, а также рекомендации по развитию сервиса - отлично!

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №2__
#
# Петр, все замечания учтены - проект принят!
#
#
# Всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличный метариал по статистике.
#
# * Курс "Вероятность и статистика" | Глеб Михайлов (free): https://www.youtube.com/playlist?list=PLQJ7ptkRY-xbHLLI66KdscKp_FJt0FsIi
#
# * Методы обнаружения выбросов: https://youtu.be/TOK7Kq7x0yc
#
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Привет!</b>
#
# Меня зовут Дмитрий Михаленко, я буду ревьюером твоего проекта. Если ты не против, то предлагаю построить наше общение на "ты" ;) Если удобнее на "вы", то нет проблем, только скажи об этом.
#
# Ниже в работе ты найдешь мои комментарии - **пожалуйста, не перемещай, не изменяй и не удаляй их**.
#
# Для наглядности я буду использовать цветовую разметку:
# <font color='green'>зеленого</font>, <font color='gold'>желтого</font> и <font color='red'>красного</font> цветов. Сейчас объясню, что они значат:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Решение на этом шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Решение на этом шаге может стать еще лучше, если внести небольшие коррективы.
# Но настаивать я не буду.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Для правильного решения задачи на этом шаге необходимо внести правки. Напоминаю, что проект не может быть принят, без их отработки.
# </div>
#
# Для продуктивной работы прошу: **если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом**
# Мне будет легче отследить изменения, если ты тоже выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
#
# Увидев у тебя ошибку, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой начальник будет поступать так же, а я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку.

# %% [markdown]
# # Напишите заголовок проекта здесь
#
# - Автор: Поляков Петр Владимирович
# - Дата: 14.03.2025 (upd. 15.03.2025)

# %% [markdown]
# ### Цели и задачи проекта
#
# <font color='#777778'>В этом блоке перечислите цель проекта и те задачи, которые вы решаете. Можно использовать описания проекта, но будет полезно, если вы сформулируете основную цель проекта самостоятельно.</font>
#
# **Цель проекта**:
# Провести всесторонний исследовательский анализ рынка заведений общественного питания Москвы на основе данных из Яндекс Карты и Яндекс Бизнес, чтобы предоставить инвесторам из фонда «Shut Up and Take My Money» обоснованные рекомендации для выбора оптимального направления для открытия нового заведения – будь то кафе, ресторан или бар.
#
# **Задачи проекта**:
#
# Анализ исходных данных:
# Оценить объем и качество полученной информации, проверить соответствие данных заявленному описанию, выявить наличие пропусков и несоответствий в типах данных, а также объединить два датасета в единое целое для дальнейшей работы.
#
# Предобработка информации:
# Провести корректировку типов данных, обработку пропущенных значений и дубликатов, а также создать дополнительные признаки (например, определить, работает ли заведение круглосуточно) для повышения информативности анализа.
#
# Исследовательский анализ:
# Выявить закономерности и особенности рынка, изучить распределение заведений по категориям и административным округам, проанализировать соотношение сетевых и независимых заведений, оценить динамику посадочных мест и рейтингов, а также исследовать корреляции между различными характеристиками (например, между рейтингом и количеством мест или ценовой категорией).
#
# Группировка и сегментация:
# Определить топ-15 популярных сетей по количеству заведений и проанализировать их средние рейтинги и ценовые показатели, а также исследовать влияние расположения (центр vs. окраины Москвы) на средний чек.
#
# Выводы и рекомендации:
# На основе проделанного анализа сформулировать ключевые выводы и разработать рекомендации для инвесторов, которые помогут определить наиболее перспективное направление для открытия нового заведения общественного питания в Москве.

# %% [markdown]
# ### Описание данных
#
# <font color='#777778'>Здесь приведите описание данных.</font>
#
# Датасет состоит из двух файлов, собранных на основе информации сервисов Яндекс Карты и Яндекс Бизнес летом 2022 года, и содержит сведения о заведениях общественного питания Москвы.
#
# Файл */datasets/rest_info.csv*:
# Содержит основные данные о заведениях:
#
# - name: название заведения.
# - address: адрес, по которому расположено заведение.
# - district: административный район Москвы (например, Центральный административный округ).
# - category: тип заведения (например, кафе, пиццерия, кофейня).
# - hours: информация о днях и часах работы заведения.
# - rating: рейтинг заведения по оценкам пользователей Яндекс Карт (максимум - 5.0).
# - chain: бинарное значение (0 или 1), указывающее, является ли заведение сетевым: 0 - не сетевое, 1 - сетевое (для небольших  сетей возможны ошибки).
# - seats: количество посадочных мест.
#
# Файл */datasets/rest_price.csv*:
# Содержит информацию о ценах и среднем чеке:
#
# - price: ценовая категория заведения (например, "средние", "ниже среднего", "выше среднего" и т.д.).
# - avg_bill: строка с информацией о среднем счёте, которая может быть представлена в виде диапазона (например, "Средний счёт: 1000-1500 р.", "Цена чашки капучино: 130–220 р.").
# - middle_avg_bill: числовое значение, рассчитанное для строк, начинающихся с "Средний счёт". Если указан диапазон - берется медиана двух значений, если одно число - оно же, иначе значение не заполняется.
# - middle_coffee_cup: числовое значение для строк, начинающихся с "Цена одной чашки капучино": рассчитывается по аналогичной логике - медиана для диапазона или само число, если оно указано отдельно.

# %% [markdown]
# ### Содержимое проекта
#
# <font color='#777778'>Перечислите основные шаги проекта или напишите оглавление. Используйте описание проекта, чтобы зафиксировать основные шаги.</font>
#
# Оглавление проекта:
#
# 1. Введение
#     - Цель проекта
#     - Задачи проекта
#     - Описание данных
#
#
# 2. Загрузка данных и первичный анализ
#     - Загрузка файлов с данными
#     - Ознакомление с данными (верхнеуровнево)
#     - Первичная оценка объема данных, типов, наличия пропусков и аномалий
#     - Объединение датасетов в единый DataFrame
#     - Предобработка данных
#
#
# 3. Приведение типов данных к требуемым форматам
#     - Анализ и обработка пропущенных значений
#     - Выявление и удаление дубликатов (нормализация текстовых столбцов)
#     - Создание новых маркеров (столбец is_24_7 для круглосуточной работы)
#     - Обработка данных о среднем чеке (расчет медианы для диапазонов)
#
#
# 4. Исследовательский анализ данных
#     - Анализ распределения заведений по категориям
#     - Исследование распределения заведений по административным округам Москвы
#     - Анализ соотношения сетевых и несетевых заведений (общий и по категориям)
#     - Анализ количества посадочных мест (выявление аномалий и типичных значений)
#     - Анализ рейтингов заведений (распределение, сравнение по категориям)
#     - Корреляционный анализ рейтинга с различными переменными (категория, район, статус сети, количество мест, ценовая категория, круглосуточная работа)
#     - Группировка данных: топ-15 популярных сетей, их средние рейтинги и ценовые характеристики
#     - Анализ вариации среднего чека по районам Москвы (центральный округ vs. прочие районы)
#
#
# 6. Итоговый вывод и рекомендации
#     - Обобщение проделанной работы
#     - Основные выводы по исследовательским вопросам
#     - Рекомендации для инвесторов на основе анализа данных
#
# ---

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Отличное введение в проект! Есть цель работы, задачи на проект, описание исходных данных и план работы.
#
# Такой детальный подход важен, чтобы твой будущий работодатель знал все ключевые моменты проекта и мог объективно оценить принимаемые тобой решения.

# %% [markdown]
# ## 1. Загрузка данных и знакомство с ними
#
# - Загрузите данные о заведениях общественного питания Москвы. Путь к файлам: `/datasets/rest_info.csv` и `/datasets/rest_price.csv`.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Это не ошибка, но рекомендую удалить ячейки оставшиеся от шаблона, чтобы когда начнешь собирать портфолио проектов не пришлось тратить на это время

# %% [markdown]
# - Познакомьтесь с данными и изучите общую информацию о них.

# %%
import pandas as pd

df_info = pd.read_csv('/datasets/rest_info.csv')
df_price = pd.read_csv('/datasets/rest_price.csv')

print("Информация о данных в rest_info.csv:")
df_info.info()
print("\nИнформация о данных в rest_price.csv:")
df_price.info()
# Out:
# Информация о данных в rest_info.csv:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8406 entries, 0 to 8405
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        8406 non-null   object
#  1   name      8406 non-null   object
#  2   category  8406 non-null   object
#  3   address   8406 non-null   object
#  4   district  8406 non-null   object
#  5   hours     7870 non-null   object
#  6   rating    8406 non-null   float64
#  7   chain     8406 non-null   int64
#  8   seats     4795 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 591.2+ KB
#
# Информация о данных в rest_price.csv:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4058 entries, 0 to 4057
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 4058 non-null   object
# ...

# %%
print("\nСтатистическая сводка для rest_info.csv (числовые столбцы):")
print(df_info.describe())

print("\nСтатистическая сводка для rest_info.csv (все столбцы):")
print(df_info.describe(include='all'))
# Out:
# Статистическая сводка для rest_info.csv (числовые столбцы):
#             rating        chain        seats
# count  8406.000000  8406.000000  4795.000000
# mean      4.229895     0.381275   108.421689
# std       0.470348     0.485729   122.833396
# min       1.000000     0.000000     0.000000
# 25%       4.100000     0.000000    40.000000
# 50%       4.300000     0.000000    75.000000
# 75%       4.400000     1.000000   140.000000
# max       5.000000     1.000000  1288.000000
#
# Статистическая сводка для rest_info.csv (все столбцы):
#                                       id  name category  \
# count                               8406  8406     8406
# unique                              8406  5614        8
# top     1b4e8491a5e642cab0f483038188c1f3  Кафе     кафе
# freq                                   1   189     2378
# mean                                 NaN   NaN      NaN
# std                                  NaN   NaN      NaN
# ...

# %%
print("\nСтатистическая сводка для rest_price.csv (числовые столбцы):")
print(df_price.describe())

print("\nСтатистическая сводка для rest_price.csv (все столбцы):")
print(df_price.describe(include='all'))
# Out:
# Статистическая сводка для rest_price.csv (числовые столбцы):
#        middle_avg_bill  middle_coffee_cup
# count      3149.000000         535.000000
# mean        958.053668         174.721495
# std        1009.732845          88.951103
# min           0.000000          60.000000
# 25%         375.000000         124.500000
# 50%         750.000000         169.000000
# 75%        1250.000000         225.000000
# max       35000.000000        1568.000000
#
# Статистическая сводка для rest_price.csv (все столбцы):
#                                       id    price                  avg_bill  \
# count                               4058     3315                      3816
# unique                              4058        4                       897
# top     dd7ab11b2a7c4ccf853a817f9ebc76e4  средние  Средний счёт:1000–1500 ₽
# freq                                   1     2117                       241
# mean                                 NaN      NaN                       NaN
# ...

# %% [markdown]
# ---
#
# ### Промежуточный вывод
#
# Сделайте промежуточный вывод о полученных данных: данные какого объёма вам предоставили, соответствуют ли данные описанию, встречаются ли в них пропуски, используются ли верные типы данных. Отметьте другие особенности данных, которые вы обнаружите на этой стадии и на которые стоит обратить внимание при предобработке.

# %% [markdown]
# **info()**
#
# Датасет rest_info.csv содержит 8406 записей и 9 столбцов, где основные поля (идентификатор, название, категория, адрес, район) заполнены полностью, а такие поля, как часы работы и количество посадочных мест, имеют пропуски (7870 и 4795 непустых значений соответственно). Типы данных соответствуют ожиданиям: строковые поля для текстовой информации, числовые для рейтинга и статуса сетевого заведения, что указывает на достаточное качество данных, но наличие пропусков требует внимания при дальнейшей работе.
#
# Датасет rest_price.csv включает 4058 записей и 5 столбцов, однако наблюдаются значительные пропуски в ряде полей: ценовая категория заполнена лишь в 3315 записях, информация о среднем счёте - в 3816, а рассчитанные показатели (middle_avg_bill и middle_coffee_cup) присутствуют только в 3149 и 535 записях соответственно. Несмотря на это, числовые данные в вычисляемых столбцах позволяют провести количественный анализ, однако необходима тщательная предобработка для устранения пропусков и обеспечения полноты данных.

# %% [markdown]
# **Датасет rest_info.csv. describe()**
#
# Анализ показывает, что рейтинг заведений высок - среднее значение составляет около 4.23 из 5 максимальных с небольшим разбросом (std = 0.47). Столбец chain указывает, что примерно 38% заведений являются сетевыми. Однако данные о количестве посадочных мест (столбец seats) доступны только для 4795 записей: среднее значение составляет 108, медиана - 75, а максимальное значение достигает 1288, что свидетельствует о наличии ошибок или выбросов.
#
# Сводка по всем столбцам демонстрирует, что идентификаторы уникальны для каждой записи, а категориальные данные, такие как name и category, содержат 5614 и 8 уникальных значений соответственно. Наиболее часто встречаемая категория – "кафе", а административный округ с наибольшим числом заведений - "Центральный административный округ". Столбец hours имеет 1307 уникальных значений, при этом наиболее распространённый режим работы - "ежедневно, 10:00–22:00".

# %% [markdown]
# **Датасет rest_price.csv. describe()**
#
# По столбцу middle_avg_bill наблюдается значительное рассеяние значений: средний показатель составляет примерно 958, при этом значения варьируются от 0 до 35000. Такое широкое распределение говорит о наличии ряда выбросов или экстремальных значений, что может указывать на неоднородность сегментов клиентов или особенности проведения операций. Аналогично, для middle_coffee_cup среднее значение составляет около 175, с меньшим разбросом (от 60 до 1568), что свидетельствует о более стабильном поведении показателя.
#
# Сводка по всем столбцам демонстрирует, что помимо числовых переменных, датасет содержит также категориальные данные, например, уникальные идентификаторы и типовые ценовые категории, представленные в столбцах id, price и avg_bill.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Хороший выбор методов для первичной оценки данных! Молодец, что так детально и всесторонне рассмотрел обе таблицы

# %% [markdown]
# ### Подготовка единого датафрейма
#
# - Объедините данные двух датасетов в один, с которым вы и продолжите работу.

# %%
# Проверяем установку phik
try:
    import phik
    from phik.report import plot_correlation_matrix
except ModuleNotFoundError:
    # !pip install phik
    import phik
    from phik.report import plot_correlation_matrix
    
df_info = pd.read_csv('/datasets/rest_info.csv')
df_price = pd.read_csv('/datasets/rest_price.csv')

df = pd.merge(df_info, df_price, on='id', how='left')

display(df.head())
# Out:
#                                  id                  name  category  \
# 0  0c3e3439a8c64ea5bf6ecd6ca6ae19f0                WoWфли      кафе
# 1  045780ada3474c57a2112e505d74b633        Четыре комнаты  ресторан
# 2  1070b6b59144425896c65889347fcff6                 Хазри      кафе
# 3  03ac7cd772104f65b58b349dc59f03ee  Dormouse Coffee Shop   кофейня
# 4  a163aada139c4c7f87b0b1c0b466a50f             Иль Марко  пиццерия
#
#                                address                         district  \
# 0           Москва, улица Дыбенко, 7/1  Северный административный округ
# 1   Москва, улица Дыбенко, 36, корп. 1  Северный административный округ
# 2       Москва, Клязьминская улица, 15  Северный административный округ
# 3  Москва, улица Маршала Федоренко, 12  Северный административный округ
# 4      Москва, Правобережная улица, 1Б  Северный административный округ
#
#                                                hours  rating  chain  seats  \
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Объединение проведено корректно! Выбрано верное значение параметра how

# %% [markdown]
# <div class="alert alert-info"> <b>Добавил импорт phik через try-except</b></div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Классная реализация

# %% [markdown]
# ## 2. Предобработка данных
#
# Подготовьте данные к исследовательскому анализу:
#
# - Изучите корректность типов данных и при необходимости проведите их преобразование.

# %%
print("Исходные типы данных:")
print(df.info())
# Out:
# Исходные типы данных:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8406 entries, 0 to 8405
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8406 non-null   object
#  1   name               8406 non-null   object
#  2   category           8406 non-null   object
#  3   address            8406 non-null   object
#  4   district           8406 non-null   object
#  5   hours              7870 non-null   object
#  6   rating             8406 non-null   float64
#  7   chain              8406 non-null   int64
#  8   seats              4795 non-null   float64
#  9   price              3315 non-null   object
#  10  avg_bill           3816 non-null   object
#  11  middle_avg_bill    3149 non-null   float64
#  12  middle_coffee_cup  535 non-null    float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 919.4+ KB
# None

# %%
categorical_columns = ['category', 'price', 'avg_bill', 'district']

df[categorical_columns] = df[categorical_columns].astype('category')

df['seats'] = pd.to_numeric(df['seats'], errors='coerce').astype('Int64')

print("\nТипы данных после преобразований:")
print(df.info())
# Out:
# Типы данных после преобразований:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8406 entries, 0 to 8405
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8406 non-null   object
#  1   name               8406 non-null   object
#  2   category           8406 non-null   category
#  3   address            8406 non-null   object
#  4   district           8406 non-null   category
#  5   hours              7870 non-null   object
#  6   rating             8406 non-null   float64
#  7   chain              8406 non-null   int64
#  8   seats              4795 non-null   Int64
#  9   price              3315 non-null   category
#  10  avg_bill           3816 non-null   category
#  11  middle_avg_bill    3149 non-null   float64
#  12  middle_coffee_cup  535 non-null    float64
# dtypes: Int64(1), category(4), float64(3), int64(1), object(4)
# memory usage: 746.2+ KB
# None

# %% [markdown]
# - Столбцы category, district, price и avg_bill преобразованы в тип category, так как они содержат ограниченное число уникальных значений (категории товаров, районы, ценовые диапазоны и пр.). P.S аналогичный пример был в курсе.
#
# - Столбец seats изначально имел тип float64, что хорошо для числовых столбцов с пропущенными значениями, но так как столбец отражает количество мест, то лучше преобразовать его в тип Int64 (целочисленное значение).
#
# - Столбцы id, name, address и hours остаются в типе object, поскольку они представляют собой текстовую информацию или идентификаторы. Числовые столбцы rating, middle_avg_bill и middle_coffee_cup, а также столбец chain уже имеют корректные числовые типы (float64 и int64) и не требуют преобразования для дальнейшего анализа.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Прекрасная работа с типами данных, могу предложить вариант понижения разрядности для некоторых из них, чтобы снизить затрачиваемую память

# %% [markdown]
# - Изучите пропущенные значения в данных: посчитайте их количество в каждом столбце датафрейме, изучите данные с пропущенными значениями и предположите гипотезы их появления. Проведите обработку пропущенных значений: вы можете заменить пропуски на определённое значение, удалить строки с пропусками или оставить их как есть.

# %%
df['hours'] = df['hours'].fillna("Unknown")

#так как в столбцах уже есть категория "unknown" то добавляем эту категорию в те ячейки в которых ее нет
for col in ['price', 'avg_bill']:
    if col in df.columns and df[col].dtype.name == 'category':
        if "Unknown" not in df[col].cat.categories:
            df[col] = df[col].cat.add_categories("Unknown")
        df[col] = df[col].fillna("Unknown")

# %% [markdown]
# - Столбцы 'hours', 'price' и 'avg_bill' содержат текстовую информацию, которую не всегда предоставляют, поэтому пропуски могут появляться при отсутствии этой информации. Заполним их значением "Unknown".

# %%
seats_median = df['seats'].median()
df['seats'] = df['seats'].fillna(seats_median)

# %% [markdown]
# - Для числового столбца 'seats' заполним пропуски медианным значением, чтобы распределение не сильно смещалось относительно мер центральной тенденции

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b>Допустимое решение, можно сделать немного точнее и сделать заполнение в пределах каждой категориии, чтобы каждый тип заведения оказывал влияние только на аналогичный ему

# %% [markdown]
# - Проверьте данные на явные и неявные дубликаты, например поля с названием и адресом заведения. Для оптимизации проверки нормализуйте данные в текстовых столбцах, например с названием заведения.

# %%
df['name_norm'] = df['name'].str.lower().str.strip()
df['address_norm'] = df['address'].str.lower().str.strip()

neyavno_duplicates = df[df.duplicated(subset=['name_norm', 'address_norm'], keep=False)]

print("Найдено неявных дубликатов (по названию, адресу и району):")
display(neyavno_duplicates[['name', 'address', 'name_norm', 'address_norm']])
# Out:
# Найдено неявных дубликатов (по названию, адресу и району):
#                            name                                  address  \
# 189                        Кафе             Москва, парк Ангарские Пруды
# 215                        Кафе             Москва, парк Ангарские пруды
# 1430                  More poke  Москва, Волоколамское шоссе, 11, стр. 2
# 1511                  More Poke  Москва, Волоколамское шоссе, 11, стр. 2
# 2211  Раковарня Клешни и Хвосты               Москва, проспект Мира, 118
# 2420  Раковарня Клешни и хвосты               Москва, проспект Мира, 118
# 3091            Хлеб да Выпечка              Москва, Ярцевская улица, 19
# 3109            Хлеб да выпечка              Москва, Ярцевская улица, 19
#
#                       name_norm                             address_norm
# 189                        кафе             москва, парк ангарские пруды
# 215                        кафе             москва, парк ангарские пруды
# ...

# %% [markdown]
# - Найдено 8 записей - неявных дубликатов

# %%
# Удаляем дубликаты по нормализованным столбцам, оставляя первую запись из каждой группы
df_clean = df.drop_duplicates(subset=['name_norm', 'address_norm'], keep='first')

print("Количество записей после удаления неявных дубликатов:", len(df_clean))
display(df_clean[['name', 'address', 'name_norm', 'address_norm']].head())
# Out:
# Количество записей после удаления неявных дубликатов: 8402
#                    name                              address  \
# 0                WoWфли           Москва, улица Дыбенко, 7/1
# 1        Четыре комнаты   Москва, улица Дыбенко, 36, корп. 1
# 2                 Хазри       Москва, Клязьминская улица, 15
# 3  Dormouse Coffee Shop  Москва, улица Маршала Федоренко, 12
# 4             Иль Марко      Москва, Правобережная улица, 1Б
#
#               name_norm                         address_norm
# 0                wowфли           москва, улица дыбенко, 7/1
# 1        четыре комнаты   москва, улица дыбенко, 36, корп. 1
# 2                 хазри       москва, клязьминская улица, 15
# 3  dormouse coffee shop  москва, улица маршала федоренко, 12
# 4             иль марко      москва, правобережная улица, 1б

# %%
#смотрим явные дубликаты по всем столбцам
all_duplicates = df[df.duplicated(keep=False)]
print("Полностью идентичные записи (дубликаты по всем столбцам):")
display(all_duplicates)

#смотрим явные дубликаты по комбинации 'name', 'address', 'district'
subset_duplicates_1 = df[df.duplicated(subset=['name', 'address', 'district'], keep=False)]
print("Дубликаты по столбцам 'name', 'address' и 'district':")
display(subset_duplicates_1[['name', 'address', 'district']])

#смотрим явные дубликаты по комбинации 'name', 'address'
subset_duplicates_2 = df[df.duplicated(subset=['name', 'address'], keep=False)]
print("Дубликаты по столбцам 'name' и 'address':")
display(subset_duplicates_2[['name', 'address']])
# Out:
# Полностью идентичные записи (дубликаты по всем столбцам):
# Empty DataFrame
# Columns: [id, name, category, address, district, hours, rating, chain, seats, price, avg_bill, middle_avg_bill, middle_coffee_cup, name_norm, address_norm]
# Index: []
# Дубликаты по столбцам 'name', 'address' и 'district':
# Empty DataFrame
# Columns: [name, address, district]
# Index: []
# Дубликаты по столбцам 'name' и 'address':
# Empty DataFrame
# Columns: [name, address]
# Index: []

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Петр, классная работа с "дублями", хвалю!

# %% [markdown]
# - Для дальнейшей работы создайте столбец `is_24_7` с обозначением того, что заведение работает ежедневно и круглосуточно, то есть 24/7:
#   - логическое значение `True` — если заведение работает ежедневно и круглосуточно;
#   - логическое значение `False` — в противоположном случае.

# %%
df['is_24_7'] = (df['hours'].str.contains('ежедневно', case=False, na=False) & 
df['hours'].str.contains('круглосуточно', case=False, na=False))

display(df[['name', 'hours', 'is_24_7']].head())
# Out:
#                    name                                              hours  \
# 0                WoWфли                             ежедневно, 10:00–22:00
# 1        Четыре комнаты                             ежедневно, 10:00–22:00
# 2                 Хазри  пн-чт 11:00–02:00; пт,сб 11:00–05:00; вс 11:00...
# 3  Dormouse Coffee Shop                             ежедневно, 09:00–22:00
# 4             Иль Марко                             ежедневно, 10:00–22:00
#
#    is_24_7
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %%
counts = df['is_24_7'].value_counts()
total = counts.sum()
count_24_7 = counts.get(True, 0)
count_not_24_7 = counts.get(False, 0)

perc_24_7 = count_24_7 / total * 100
perc_not_24_7 = count_not_24_7 / total * 100

print(f"Круглосуточно (24/7): {count_24_7} заведений ({perc_24_7:.2f}%)")
print(f"Не круглосуточно: {count_not_24_7} заведений ({perc_not_24_7:.2f}%)")
# Out:
# Круглосуточно (24/7): 730 заведений (8.68%)
# Не круглосуточно: 7676 заведений (91.32%)

# %% [markdown]
# ---
#
# ### Промежуточный вывод
#
# После предобработки данных напишите промежуточный вывод о проведённой работе. Отразите количество или долю отфильтрованных данных, если вы что-то удаляли.

# %% [markdown]
# ***После предобработки данных были выполнены следующие операции:***
#
# >>Проведено преобразование типов данных: столбцы category, district, price и avg_bill переведены в тип category, а столбец seats преобразован в целочисленный тип Int64.
#
# >>Были изучены и обработаны пропуски: для текстовых столбцов (hours, price, avg_bill) пропуски заполнены значением «Unknown», а для числового столбца seats - медианным значением. Кроме того, при проверке на неявные дубликаты (на основе нормализованных значений столбцов name и address) было обнаружено 8 записей, что позволило уменьшить общее число записей с 8406 до 8402.
#
# >>Также был создан новый столбец is_24_7, который определяет, работает ли заведение круглосуточно и ежедневно. По итогам анализа, 8.68% заведений (730 записей) работают 24/7, а 91.32% (7676 записей) — нет. Эти результаты подтверждают, что проведённая предобработка позволила очистить и структурировать данные для дальнейшего исследовательского анализа.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Этап предобработки в целом выполнен последовательно и качественно, ты молодец! Отдельно отмечу твое внимание к деталям, это очень полезное качество выгодно подчеркивающее твои аналитические способности)

# %% [markdown]
# ## 3. Исследовательский анализ данных
# Проведите исследовательский анализ исходных данных.
#
# При исследовании данных используйте визуализации. Проверьте, что для каждого случая подобран оптимальный тип визуализации с корректным оформлением. У графика должен быть заголовок, понятные подписи по осям, при необходимости легенда, а его размер является оптимальным для изучения.
#
# После исследования каждого пункта оставляйте небольшой комментарий с выводом или обсуждением результата. В конце шага обобщите результаты, выделив, по вашему мнению, самые важные.

# %% [markdown]
# ---
#
# ### Задача 1
#
# Какие категории заведений представлены в данных? Исследуйте количество объектов общественного питания по каждой категории. Результат сопроводите подходящей визуализацией.

# %%
import matplotlib.pyplot as plt

category_counts = df['category'].value_counts()

plt.figure(figsize=(12, 6))
category_counts.plot(kind='bar', color='skyblue', edgecolor='black')

plt.title('Распределение заведений по категориям', fontsize=14)
plt.xlabel('Категория заведения', fontsize=12)
plt.ylabel('Количество заведений', fontsize=12)

plt.show()

# %% [markdown]
# В топ-3 категории заведения входят: кафе, рестораны, кофейни.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Результаты интерпретированы корректно, я бы рекомендовал добавить либо таблицу с результатами либо подписи рядов данных, чтобы пользователи могли взять точные значения по категориям в случае необходимости

# %% [markdown]
# ---
#
# ### Задача 2
#
# Какие административные районы Москвы присутствуют в данных? Исследуйте распределение количества заведений по административным районам Москвы, а также отдельно распределение заведений каждой категории в Центральном административном округе Москвы. Результат сопроводите подходящими визуализациями.

# %%
district_counts = df['district'].value_counts()

plt.figure(figsize=(12, 6))
district_counts.plot(kind='bar', color='lightcoral', edgecolor='black')

plt.title('Количество заведений по административным районам Москвы', fontsize=14)
plt.xlabel('Административный район', fontsize=12)
plt.ylabel('Количество заведений', fontsize=12)

plt.show()

# %%
df_cao = df[df['district'] == 'Центральный административный округ']
cao_category_counts = df_cao['category'].value_counts()

plt.figure(figsize=(12, 6))
cao_category_counts.plot(kind='bar', color='seagreen', edgecolor='black')

plt.title('Распределение заведений по категориям в ЦАО', fontsize=14)
plt.xlabel('Категория заведения', fontsize=12)
plt.ylabel('Количество заведений', fontsize=12)


plt.show()

# %% [markdown]
# ЦАО является лидером среди районов Москвы по числу объектов общепита. Более 2 тыс. точек располагаются в ЦАО, в то время как в остальных районах их число не превышает 1 тыс. (в каждом). Если рассматривать распределение категорий объектов в ЦАО, то самым популярным является тип "ресторан", а самым непопулярным - "булочная". В целом структура лидеров по типу в ЦАО повторяет струткру в Москве (рестораны, кафе и кофейни).

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b>  С распределением заведений по районам тоже все ОК. Небольшие дополнительные рекомендации по оформлению: можно повернуть подписи на 45 град. либо перестроить графики в виде линейчатой диаграммы. Это немного упростит чтение подписей на осях

# %% [markdown]
# ---
#
# ### Задача 3
#
# Изучите соотношение сетевых и несетевых заведений в целом по всем данным и в разрезе категорий заведения. Каких заведений больше — сетевых или несетевых? Какие категории заведений чаще являются сетевыми? Исследуйте данные, ответьте на вопросы и постройте необходимые визуализации.

# %%
chain_counts = df['chain'].value_counts()
labels = ['Несетевые', 'Сетевые']

plt.figure(figsize=(7, 7))
plt.pie(chain_counts, labels=labels, autopct='%1.1f%%', colors=['lightblue', 'salmon'], startangle=90, wedgeprops={'edgecolor': 'black'})
plt.title('Соотношение сетевых и несетевых заведений')
plt.show()

# %%
#ошибка! исследовано абсолютное значение, но нужно перевести в относительные (доли)
category_chain_counts = df.groupby(['category', 'chain']).size().unstack()

plt.figure(figsize=(12, 6))
category_chain_counts.plot(kind='bar', stacked=True, color=['lightblue', 'salmon'], edgecolor='black')

plt.title('Распределение сетевых и несетевых заведений по категориям', fontsize=14)
plt.xlabel('Категория заведения', fontsize=12)
plt.ylabel('Количество заведений', fontsize=12)
plt.legend(['Несетевые', 'Сетевые'])

plt.show()

# %% [markdown]
# Соотношение сетевых и несетевых заведений - в пользу вторых. Несетевыми являются почти 62% заведений, в то время как сетевыми - 38%. Распределение сетевых и несетевых заведений по категориям показывает что наибольшая доля несетевых заведений наблюдается у столовых, а наименьшая у булочных и кафе.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Петр, тут я не могу полностью согласиться с тобой. Обрати внимание на то, что ты не учитываешь соотношение сетевых и несетевых зваедений и строишь график по абсолютным значениям. Но ведь количество булочных, например, сильно отличается от количества кафе, поэтому правильно исследовать доли

# %%
#отработка ошибки. 
#доля сетевых и несетевых заведений в каждой категории
category_chain_proportion = df.groupby('category')['chain'].value_counts(normalize=True).unstack()

plt.figure(figsize=(12, 6))
category_chain_proportion.plot(kind='bar', stacked=True, color=['lightblue', 'salmon'], edgecolor='black')

plt.title('Доля сетевых и несетевых заведений по категориям', fontsize=14)
plt.xlabel('Категория заведения', fontsize=12)
plt.ylabel('Доля заведений', fontsize=12)
plt.legend(['Несетевые', 'Сетевые'], title="Тип заведения")
plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий по исправлению ошибки:</b> Использованы относительные показатели для анализа насколько сетевые игроки контролируют категории общепита. Теперь график наглядно показывает в каких сегментах присутствие сетевых игроков выше (булочные, кофейни, пиццерии), а в каких ниже (бар/паб, столовые, рестораны). При высокой доле сетевых игроков ситуация на рынке более монополизирована, при низкой доле "порог входа" ниже и у новых заведений больше шансов завоевать долю рынка.</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Прекрасное уточнение исследования и очень точные подробные выводы по задаче!

# %% [markdown]
# ---
#
# ### Задача 4
#
# Исследуйте количество посадочных мест в заведениях. Встречаются ли в данных аномальные значения или выбросы? Если да, то с чем они могут быть связаны? Приведите для каждой категории заведений наиболее типичное для него количество посадочных мест. Результат сопроводите подходящими визуализациями.

# %%
import seaborn as sns
import numpy as np

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['seats'], color='lightblue')

plt.title('Распределение количества посадочных мест', fontsize=14)
plt.xlabel('Количество посадочных мест', fontsize=12)
plt.show()

# %% [markdown]
# Диаграмма размаха показывает, что среди значений по столбцу seats достаточно много выбросов. То есть распределение похоже неравномерное и с большим перекосом "вправо", но возможно это не ошибки, а действительно рестораны (скорее всего банкетные залы) на большое число посадочных мест.

# %%
Q1 = df['seats'].quantile(0.25)
Q3 = df['seats'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['seats'] < lower_bound) | (df['seats'] > upper_bound)]
print(f"Количество выбросов: {len(outliers)}")
# Out:
# Количество выбросов: 1940

# %% [markdown]
# Количество выбросов посчитали с помощью межквартильного размаха (IQR). Границы для выбросов определили как -1,5 от Q1 или +1,5 от Q3. Количество выбросов по данной методике составило 1940

# %%
category_seats = df.groupby('category')['seats'].median().sort_values()

plt.figure(figsize=(12, 6))
category_seats.plot(kind='bar', color='lightcoral', edgecolor='black')

plt.title('Медианное количество посадочных мест по категориям заведений', fontsize=14)
plt.xlabel('Категория заведения', fontsize=12)
plt.ylabel('Медианное количество посадочных мест', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
seats_stats = df.groupby('category')['seats'].agg(
    mode=lambda x: x.mode().iloc[0] if not x.mode().empty else None,
    median='median',
    mean='mean'
)
display(seats_stats)
# Out:
#                  mode  median        mean
# category
# бар,паб            75    75.0  105.301961
# булочная           75    75.0   83.316406
# быстрое питание    75    75.0   88.827529
# кафе               75    75.0   86.530698
# кофейня            75    75.0   94.239915
# пиццерия           75    75.0   88.151659
# ресторан           75    75.0  104.182085
# столовая           75    75.0   87.885714

# %% [markdown]
# Мы вывели три меры центральной тенденции - моду, медиану и среднее арифметическое посадочных мест по категориям. Видно, что мода и медиана совпадают, а среднее арифметическое их превышает. Когда превышение небольшое, как у булочной или кафе, то можно говорить о более равномерном распределении, а если разница большая (напр. бар/паб или ресторан), то вариативность показателя выше и распределении неравномерно с хвостами "вправо".

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Исследование проведено очень детально и применен рациональный подход использования межквартильного размаха для фильтрации выбросов, такой подход поможет заказчику всесторонне оценить рынок!

# %% [markdown]
# ---
#
# ### Задача 5
#
# Исследуйте рейтинг заведений. Визуализируйте распределение средних рейтингов по категориям заведений. Сильно ли различаются усреднённые рейтинги для разных типов общепита?

# %%
category_ratings = df.groupby('category')['rating'].mean().sort_values()

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
category_ratings.plot(kind='bar', color='royalblue', edgecolor='black')

plt.title('Распределение средних рейтингов по категориям заведений', fontsize=14)
plt.xlabel('Категория заведения', fontsize=12)
plt.ylabel('Средний рейтинг', fontsize=12)
plt.ylim(4, 4.5)  # решил ограничить ось Y от 4 до 4.5, выглядит наглядней:)

plt.show()

# %% [markdown]
# Наиболее высокие рейтинги у баров/пабов, пиццерий и ресторанов. Аутсайдерами являются объекты быстрого питания.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1<a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Для наглядности предлагаю ограничить значения по оси Y. Например от 3.8 до 5.

# %% [markdown]
# ---
#
# ### Задача 6
#
# Изучите, с какими данными показывают самую сильную корреляцию рейтинги заведений? Постройте и визуализируйте матрицу корреляции рейтинга заведения с разными данными: его категория, положение (административный район Москвы), статус сетевого заведения, количество мест, ценовая категория и признак, является ли заведения круглосуточным. Выберите самую сильную связь и проверьте её.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Рекомендую устанавливать библиотеки через `try-except`, чтобы лишний раз не прогружать окружение. И в соответствии с правилами оформления лучше конечно делать это в начале проекта. Так будет проще вести отладку и проверять зависимости библиотек

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Но что точно лучше убрать это повторный импорт отдельных библиотек, датасетов и их объединение

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>

# %%
#убрал все лишние импорты и объединение таблиц. добавил импорт phik в самом начале файла - в раздел с объединением таблиц.
interval_cols = ['rating', 'chain', 'seats', 'middle_avg_bill', 'middle_coffee_cup', 'is_24_7']

# Убираем ненужные столбцы 
df_filtered = df.drop(columns=['id', 'name', 'address', 'hours', 'name_norm', 'address_norm'], errors='ignore')

phik_matrix = df_filtered.phik_matrix(interval_cols=interval_cols)

plt.figure(figsize=(20, 12))
plot_correlation_matrix(phik_matrix.values, x_labels=phik_matrix.columns, y_labels=phik_matrix.index)
plt.title("Матрица Phi_K корреляции рейтинга с другими факторами")
plt.show()

correlation_with_rating = phik_matrix['rating'].drop('rating').sort_values(ascending=False)
display(correlation_with_rating)

#добавил столбец (avg_bill) с наибольшими корреляциями 
correlation_with_avg_bill = phik_matrix['avg_bill'].drop('avg_bill').sort_values(ascending=False)
display(correlation_with_avg_bill)
# Out:
# avg_bill             0.453687
# price                0.220295
# middle_avg_bill      0.211868
# district             0.200691
# category             0.190003
# chain                0.108092
# seats                0.000000
# middle_coffee_cup    0.000000
# Name: rating, dtype: float64
# middle_avg_bill      1.000000
# middle_coffee_cup    1.000000
# price                0.989961
# category             0.786757
# chain                0.473329
# rating               0.453687
# district             0.442033
# seats                0.000000
# Name: avg_bill, dtype: float64

# %% [markdown]
#  По матрице корреляций видно, что существует функциональная зависимость среднего чека и средней цены чашки кофе, а также цены. Сильная положительная корреляция наблюдается между средним чеком и категорией (0.79). Почти отсутствует корреляция между средней ценой и статусом сетевого ресторана (0.45), рейтингом (0.45), районом (0.44).

# %% [markdown]
# <div class="alert alert-info"> <b>добавил столбец (avg_bill) с наибольшими корреляциями </b></div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Корелляции рассмотрены, давай выведем результаты по наибольшей в виде сводной таблицы, чтобы пользователи видели срузу цены по категориям

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Супер

# %% [markdown]
# ---
#
# ### Задача 7
#
# Сгруппируйте данные по названиям заведений и найдите топ-15 популярных сетей в Москве. Для них посчитайте значения среднего рейтинга. Под популярностью понимается количество заведений этой сети в регионе. К какой категории заведений они относятся? Результат сопроводите подходящими визуализациями.

# %%
df_chain = df[df['chain'] == 1]

top_chains = df_chain.groupby('name').agg(
    num_locations=('id', 'count'),
    avg_rating=('rating', 'mean'),
    category=('category', 'first')  
).sort_values(by='num_locations', ascending=False).head(15)

plt.figure(figsize=(12, 6))
top_chains.sort_values(by='num_locations', ascending=True).plot(
    kind='barh', y='num_locations', color='royalblue', edgecolor='black', legend=False
)
plt.title('Топ-15 популярных сетей в Москве по количеству заведений', fontsize=14)
plt.xlabel('Количество заведений', fontsize=12)
plt.ylabel('Название сети', fontsize=12)
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> С графиком "Топ-15" разобрался блестяще!

# %% [markdown]
# Наиболее популярными сетями в Москвы стали: Шоколадница, Домино'с Пицца, Додо Пицца, One Price Coffee? Яндекс Лавка, Cofix, Prime, Хинкальная, КОФЕПОРТ, Кулинарная лавка братьев Караваевых, Теремок, Чайхана, Буханка, CofeFest, Му-Му

# %%
df_chain = df[df['chain'] == 1]

top_chains = df_chain.groupby('name').agg(
    num_locations=('id', 'count'),  # Количество заведений
    avg_rating=('rating', 'mean'),  # Средний рейтинг
    category=('category', 'first'),  # Категория заведения
    median_seats=('seats', 'median'),  # Медиана количество мест
    mode_price=('price', lambda x: x.mode().iloc[0] if not x.mode().empty else None),  # Мода по ценам
    mode_avg_bill=('avg_bill', lambda x: x.mode().iloc[0] if not x.mode().empty else None)  # Мода по среднему чеку
).sort_values(by='num_locations', ascending=False).head(15)

display(top_chains)
# Out:
#                                      num_locations  avg_rating  \
# name
# Шоколадница                                    120    4.177500
# Домино'с Пицца                                  76    4.169737
# Додо Пицца                                      74    4.286486
# One Price Coffee                                71    4.064789
# Яндекс Лавка                                    69    3.872464
# Cofix                                           65    4.075385
# Prime                                           50    4.116000
# Хинкальная                                      44    4.322727
# КОФЕПОРТ                                        42    4.147619
# Кулинарная лавка братьев Караваевых             39    4.394872
# Теремок                                         38    4.123684
# Чайхана                                         37    3.924324
# CofeFest                                        32    3.984375
# Буханка                                         32    4.396875
# ...

# %% [markdown]
# - Лидеры по количеству заведений - Шоколадница (120 точек), Домино'с Пицца (76), Додо Пицца (74), One Price Coffee (71), Яндекс Лавка (69). Основную часть топа занимают кофейни, пиццерии и рестораны быстрого питания.
#
# - Самый высокий средний рейтинг у «Буханка» (4.40), «Кулинарная лавка братьев Караваевых» (4.39) и «Хинкальная» (4.32), что говорит о высокой лояльности клиентов. В то же время Яндекс Лавка (3.87) и Чайхана (3.92) имеют самые низкие оценки среди топа.
#
# - Медианное количество посадочных мест варьируется: у Му-Му (155 мест) и Шоколадницы (96 мест) - больше всего, тогда как у Буханки (48 мест) и Яндекс Лавки (46 мест) — меньше.
#
# - По ценам и среднему чеку: большинство заведений имеют ценовую категорию «средние», а самые доступные цены - у Cofix (низкие, капучино от 60 ₽) и КОФЕПОРТ (капучино 90-100 ₽). Среди ресторанов самая высокая мода среднего чека у Хинкальной (1000-1200 ₽).

# %% [markdown]
# <div class="alert alert-info"> <b>Убрал все лишние импорты и объединения</b></div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>Выше снова есть ненужные импорты и объединение

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Молодец, не стоит перегружать проект дублирующимися действиями

# %% [markdown]
# ---
#
# ### Задача 8
#
# Изучите вариацию среднего чека заведения (столбец `middle_avg_bill`) в зависимости от района Москвы. Проанализируйте цены в Центральном административном округе и других. Как удалённость от центра влияет на цены в заведениях? Результат сопроводите подходящими визуализациями.

# %%
district_avg_bill = df.groupby("district")["middle_avg_bill"].median().sort_values()
district_counts = df['district'].value_counts()

fig, ax1 = plt.subplots(figsize=(12, 6))

# максимум по шкале Y
max_value = 2500

# График среднего чека
district_avg_bill.plot(kind="bar", color="royalblue", edgecolor="black", ax=ax1, position=1, width=0.4)
ax1.set_ylabel("Средний чек (руб.)", fontsize=12, color="royalblue")
ax1.set_xlabel("Административный округ", fontsize=12)
ax1.tick_params(axis='y', labelcolor="royalblue")
ax1.set_xticklabels(district_avg_bill.index, rotation=45, ha="right")
ax1.set_ylim(0, max_value)  # Устанавливаем одинаковый предел оси Y

ax2 = ax1.twinx()
district_counts[district_avg_bill.index].plot(kind="bar", color="lightcoral", edgecolor="black", ax=ax2, position=0, width=0.4, alpha=0.7)
ax2.set_ylabel("Количество заведений", fontsize=12, color="lightcoral")
ax2.tick_params(axis='y', labelcolor="lightcoral")
ax2.set_ylim(0, max_value)  


plt.title("Средний чек и количество заведений по административным округам Москвы", fontsize=14)


plt.show()

# %% [markdown]
# График "Средний чек и количество заведений по административным округам Москвы" показывает, что самый высокий средний чек в ЦАО и ЗАО (ок 1000 р.). Далее наблюдается уменьшение среднего чека при движении на Запад: СЗАО, САО, ЮЗАО. Для примера также выведено число заведений, но зависимости между показателями нет.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Результаты получились вполне правдоподобные с учетом разной "специализации" районов города)

# %% [markdown]
# ---
#
# ### Промежуточный вывод
#
# Обобщите полученные результаты, выделив, по вашему мнению, самые важные.

# %% [markdown]
# 1. Распределение заведений по категориям и районам:
#
# Лидерами по числу заведений стали кафе, рестораны и кофейни.
# ЦАО является основным районом сосредоточения объектов общественного питания - здесь их более 2000. В других округах число заведений не превышает 1000 в каждом.
# В ЦАО доминируют рестораны, кафе и кофейни, что соответствует общему распределению по Москве.
#
# 2. Сетевые и несетевые заведения:
#
# 62% заведений - несетевые, а 38% – сетевые.
# Сетевые заведения чаще встречаются среди булочных и кафе, а несетевые - среди столовых и баров/пабов.
#
# 3. Анализ посадочных мест:
#
# В распределении есть выбросы, особенно у крупных ресторанов и банкетных залов.
# Среднее количество мест выше медианы, что указывает на правостороннее смещение данных.
# Больше всего посадочных мест в ресторанах и пиццериях, меньше всего - в кофейнях и булочных.
#
# 4. Рейтинги заведений:
#
# Наиболее высокие рейтинги у баров/пабов, пиццерий и ресторанов.
# Самые низкие оценки – у объектов быстрого питания.
# Среди сетевых брендов самый высокий рейтинг у "Буханка" (4.40), самый низкий - у "Яндекс Лавка" (3.87).
#
# 5. Популярные сети:
#
# ТОП-3 по количеству точек:
# Шоколадница (120 точек)
# Домино'с Пицца (76 точек)
# Додо Пицца (74 точки)
# Большинство топ-заведений относятся к кофейням, пиццериям и ресторанам быстрого питания.
#
# 6. Средний чек и цены в зависимости от района:
#
# Средний чек выше в ЦАО и ЗАО (около 1000 руб.).
# В более удалённых районах (ЮЗАО, САО, СЗАО) чек постепенно снижается.
# Самые доступные цены - в Cofix (капучино от 60 руб.) и КОФЕПОРТ (капучино 90–100 руб.).

# %% [markdown]
# ## 4. Итоговый вывод и рекомендации
#
# По результатам проведённого исследовательского анализа данных сформулируйте итоговый вывод и рекомендации для заказчика. Старайтесь акцентировать внимание на ключевых моментах исследования.
#
# При составлении вывода придерживайтесь такой структуры:
#
# 1. Общий обзор проделанной работы.
# 2. Ответы на исследовательские вопросы, или главные выводы.
# 3. Рекомендации на основе анализа данных.

# %% [markdown]
# # Общий обзор проделанной работы
# В ходе исследования были объединены два датасета с информацией о заведениях общественного питания в Москве и их ценах. Данные прошли предобработку:
#
# Коррекция типов данных (категориальные признаки, числовые переменные).
# Обнаружение и обработка пропущенных значений (замена текстовых пропусков на "Unknown", заполнение медианой количества посадочных мест).
# Поиск и удаление неявных дубликатов (найдено и удалено 8 записей).
# Добавление нового столбца is_24_7 для анализа круглосуточных заведений.
# Проведение исследовательского анализа: визуализация и статистика по категориям, районам, сетевым и несетевым заведениям, ценовым сегментам и рейтингу заведений.
# На основе анализа выявлены ключевые закономерности рынка общественного питания в Москве.

# %% [markdown]
# # Основные выводы
# Распределение заведений по категориям
#
# В Москве преобладают кафе, рестораны и кофейни.
# В Центральном административном округе (ЦАО) сосредоточено более 2000 заведений, в других округах количество не превышает 1000.
# Рестораны, кафе и кофейни доминируют в ЦАО, а булочные и столовые встречаются реже.
# Сетевые и несетевые заведения
#
# 62% заведений несетевые, а 38% – сетевые.
# Столовые – наиболее несетевой сегмент, а булочные и кафе чаще всего являются сетевыми.
# Посадочные места и их распределение
#
# Среднее количество мест сильно варьируется.
# Выбросы по количеству посадочных мест связаны с банкетными залами и крупными ресторанами.
# У сетевых кофеен и пиццерий (например, Додо Пицца, Cofix, Prime) посадочных мест меньше, чем у ресторанов.
# Рейтинги заведений
#
# Средний рейтинг по Москве 4.23 из 5, что указывает на высокую лояльность клиентов.
# Лучшие рейтинги у баров/пабов, пиццерий и ресторанов.
# Быстрое питание и заведения формата "еда навынос" получают более низкие оценки.
# Среди сетевых заведений лидеры по среднему рейтингу:
# Буханка (4.40)
# Кулинарная лавка братьев Караваевых (4.39)
# Хинкальная (4.32)
# Популярные сети
#
# ТОП-3 по количеству точек:
# Шоколадница (120 точек)
# Домино'с Пицца (76 точек)
# Додо Пицца (74 точки)
# Основная доля сетей – кофейни, пиццерии и рестораны быстрого питания.
# Средний чек и ценовая политика
#
# Средний чек в Москве сильно варьируется: от 60 ₽ (кофе в Cofix) до 1200 ₽ (Хинкальная).
# Самые дорогие районы – ЦАО и ЗАО (медианный чек ~1000 ₽).
# Чем дальше от центра – тем дешевле заведения.
# Му-Му, Cofix и One Price Coffee ориентированы на доступные цены, тогда как Prime, Шоколадница и Хинкальная работают в среднем и высоком ценовых сегментах.

# %% [markdown]
# # Рекомендации для заказчика
#
# - Рассмотреть открытие заведений в ЦАО и ЗАО, так как эти районы демонстрируют высокий средний чек и большой поток клиентов.
#
# - Анализировать сетевые форматы для кафе, пиццерий и фастфуда – именно эти категории показывают высокую популярность среди клиентов.
#
# - Ориентироваться на тренды ценовой политики:
# -- Бюджетный сегмент (Cofix, One Price Coffee) – низкие цены и большой поток клиентов.
# -- Средний сегмент (Шоколадница, Prime) – баланс цен и качества.
# -- Высокий сегмент (Хинкальная, рестораны) – эксклюзивное меню и премиум-сервис.
# -- Развивать несетевые форматы заведений в столовых, барах и пабах – там пока низкая конкуренция сетевых брендов.
# -- Продумать стратегию управления рейтингами – низкие оценки могут быть связаны с качеством обслуживания или несоответствием ожиданий клиентов.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Ярослав, итоговый вывод, как и весь проект в целом, выполнен классно! Он структурирован и содержит  наиболее значиные результаты по каждому пункту работы, есть и полезные рекомендации для бизнеса.  Очень интересный и разумный подход сделать упор при их написании на наиболее привлекательных  по твоему мнению направлениях инвестирования
#
# Итоговые выводы - важная часть работы и в твоих будующих реальных проектах советую уделять ей особое внимание. Бывают ситуации, когда у руководства нет времени вникать в весь проект и оценка твоих действий будет проводиться именно по ним.
#
# Пожалуйста, не забудь актуализировать их после корректировки неточностей выше

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту ревьювера**:
#      Спасибо за  проект! Ты приложил много усилий, чтобы довести его до конца, проделана огромная работа, и это видно невооруженным глазом, ты большой молодец! Но у меня осталось несколько  дополнений с которыми проект может стать еще лучше.
#
# **Отмечу положительные моменты**:
#
#     1. Все разложено по полочкам, всегда понятен ход твоих мыслей, приятно смотреть.
#
#     2. Подробные и логичные выводы на всех этапах работы.
#
#     3. Уместные визуализации.
#
# **На что стоит обратить внимание**:
#
#     1. Пересмотр подхода к анализу сетевых/ не сетевых заведений
#
#     2. Устранение повторных импортов
#
#     3. Актуализация выводов
#
#
# **Удачи и жду твой проект на повторное ревью!**

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Петр, проект был не простой, но ты уверенно справился! У тебя отлично развиты аналитические способностии, владение инструментарием и умение формулировать выводы. Желаю успешного и интересного продолжения учебы!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту ревьювера V2**:
#      Ошибки исправлены, проект зачтен. Поздравляю тебя, еще одна аналитическая работа попадает в твое портфолио
